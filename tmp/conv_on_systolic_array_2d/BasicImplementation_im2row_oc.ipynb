# %%
import numpy as np
import pandas as pd
from typing import List, Optional

# %%
pd.set_option('display.max_rows', None)

# %%
def _output_size(I, K, P, S): 
    return int((I - K + 2*P)/(S)) + 1

activations_size = 6 
kernel_size = 4 
padding = 0
stride = 1
output_size = _output_size(activations_size, kernel_size, padding, stride)
num_patches = output_size ** 2

# %%
f"{output_size}x{output_size}"
# Out:
# '3x3'

# %%
I, J = np.indices((activations_size, activations_size))
activations = np.char.add(np.char.add('A', I.astype(str)), J.astype(str))

# %%
I, J = np.indices((kernel_size, kernel_size))
kernel = np.char.add(np.char.add('K', I.astype(str)), J.astype(str))

# %%
equations = []
patches = [] 
inv_patches = [] 

num_rows = (activations_size - kernel_size) // stride + 1
num_cols = (activations_size - kernel_size) // stride + 1

equations_matrix = [[None for _ in range(num_cols)] for _ in range(num_rows)]

for i in range(0, activations_size - kernel_size + 1, stride):
    for j in range(0, activations_size - kernel_size + 1, stride):
        patch = activations[i:i+kernel_size, j:j+kernel_size]
        inv_patch = activations[i:i+kernel_size, j:j+kernel_size].T
        patches.append(patch)
        inv_patches.append(inv_patch)
        
        terms = []
        for a in range(kernel_size):
            for b in range(kernel_size):
                terms.append(f"{patch[a, b]}*{kernel[a, b]}")
        equation = " + ".join(terms)
        
        row_idx = i // stride
        col_idx = j // stride
        equations_matrix[row_idx][col_idx] = equation

# %%
split_equations_dict = {'0': '000_0'}

for row_id in range(len(equations_matrix)):
    for col_id in range(len(equations_matrix[row_id])):
        equation = equations_matrix[row_id][col_id]
        terms = equation.split(" + ")
        split_eq = []

        for i in range(4):
            split_eq.append(" + ".join(terms[i*4 : (i+1)*4]))
        
        for i, eq in enumerate(split_eq):
            key = f"C{row_id}{col_id}_{i}"
            split_equations_dict[eq] = key

# %%
patches = np.array(patches)
inv_patches = np.array(inv_patches)

# %%
class PE:
    # links: [0: left, 1: up, 2: right, 3: down]
    def __init__(self, links: Optional[List['PE']] = None):
        if links is None:
            links = [None, None, None, None]
        self.links = links
        self.activation = "0"
        self.weight = '--'
        self.accumulation: str = "0"
    
    def _input(self, activation: str):
        self.activation = activation
    
    def _weight(self, weight: str):
        self.weight = weight
    
    def shift(self, shift_direction: int, activation_flag: bool):
        neighbor = self.links[shift_direction]
        if neighbor is not None:
            if activation_flag:
                neighbor._input(self.activation)
            else:
                neighbor._weight(self.weight)

class SystolicArray:
    def __init__(self, size: int):
        self.size = size
        self.buffer = []  
        self.array = self._setup_array()
    
    def _setup_array(self):
        array = [[PE() for _ in range(self.size)] for _ in range(self.size)]
        for i in range(self.size):
            for j in range(self.size):
                left = array[i][j-1] if j > 0 else None
                up = array[i-1][j] if i > 0 else None
                right = array[i][j+1] if j < self.size - 1 else None
                down = array[i+1][j] if i < self.size - 1 else None
                array[i][j].links = [left, up, right, down]
        return array

    def print_array(self):
        for i in range(self.size):
            row_parts = []
            for pe in self.array[i]:
                act_str = pe.activation.ljust(4)
                weight_str = pe.weight.ljust(4)
                
                if pe.accumulation.strip() == "0":
                    parts = ["0", "0", "0", "0"]
                else:
                    parts = [p.strip() for p in pe.accumulation.split('+')]
                    while len(parts) < 4:
                        parts.append("0")
                    parts = parts[:4]
                parts = [p.ljust(8) for p in parts]
                acc_str = " + ".join(parts)
                
                row_parts.append(f"[A:{act_str} | W:{weight_str} | Acc:{acc_str}]")
            print(" | ".join(row_parts))

    def cycle(self, new_activations: Optional[List[str]] = None):
        if new_activations:
            for i in range(self.size):
                #  shift activations rightward
                for j in range(self.size - 1, 0, -1):
                    self.array[i][j].activation = self.array[i][j-1].activation
                # shift the new activation into column 0.
                self.array[i][0].activation = new_activations[i]
        
        bottom_row = [self.array[self.size - 1][j].accumulation for j in range(self.size)]
        self.buffer.append(bottom_row)
        # Look to get the equations
        
        for j in range(self.size):
            # save previous cycle's accumulations for column j
            prev_acc = [self.array[i][j].accumulation for i in range(self.size)]
            
            # Update the accumulation in row 0 for column j.
            cell0 = self.array[0][j]
            prod0 = f"{cell0.activation}*{cell0.weight}" if cell0.activation not in ["0", "--"] else "0"
            cell0.accumulation = prod0
            
            for i in range(1, self.size):
                cell = self.array[i][j]
                prod = f"{cell.activation}*{cell.weight}" if cell.activation not in ["0", "--"] else "0"
                inherited = prev_acc[i-1]
                if inherited == "0":
                    new_acc = prod
                else:
                    new_acc = inherited + (f" + {prod}" if prod != "0" else "")
                cell.accumulation = new_acc if new_acc != "" else "0"

# %%
class Conv2dSimulator:
    def __init__(self, array_size: int):
        self.input_buffers = [
            [],              
            ["0"],           
            ["0", "0"],      
            ["0", "0", "0"] 
        ]
        
        self.systolic_array = SystolicArray(array_size)
        self.outputs = [] 

    def add_patches(self, patches: List[np.ndarray]):
        for i, patch in enumerate(patches):
            flat_patch = patch.flatten().tolist()
            # Use round-robin assignment across the buffers
            self.input_buffers[i % len(self.input_buffers)].extend(flat_patch)

    def cycle(self):
        new_activations = []
        for i in range(self.systolic_array.size):
            if self.input_buffers[i]:
                new_act = self.input_buffers[i].pop(0)
            else:
                new_act = "0"
            new_activations.append(new_act)
        
        print("New activations:", new_activations)
        self.systolic_array.cycle(new_activations=new_activations)
        self.systolic_array.print_array()
        output = self.systolic_array.buffer[-1]
        translated_equations = [] 
        for _out in output: 
            try: 
                translated_equations.append(split_equations_dict[_out])
            except:
                translated_equations.append('Cxx_x')
        self.outputs.append(translated_equations)
        print("Output: ", translated_equations)
        return translated_equations

# %%
conv_sim = Conv2dSimulator(kernel_size)
conv_sim.add_patches(patches)


kernel_test = kernel.T
for i in range(kernel_size):
    for j in range(kernel_size):
        conv_sim.systolic_array.array[i][j].weight = kernel_test[i, j]

for cycle_num in range(100):
    out = conv_sim.cycle()
    print()
# Out:
# New activations: ['A00', '0', '0', '0']
# [A:A00  | W:K00  | Acc:A00*K00  + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['A01', 'A01', '0', '0']
# [A:A01  | W:K00  | Acc:A01*K00  + 0        + 0        + 0       ] | [A:A00  | W:K10  | Acc:A00*K10  + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:A01  | W:K01  | Acc:A00*K00  + A01*K01  + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['A02', 'A02', 'A02', '0']
# [A:A02  | W:K00  | Acc:A02*K00  + 0        + 0        + 0       ] | [A:A01  | W:K10  | Acc:A01*K10  + 0        + 0        + 0       ] | [A:A00  | W:K20  | Acc:A00*K20  + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:A02  | W:K01  | Acc:A01*K00  + A02*K01  + 0        + 0       ] | [A:A01  | W:K11  | Acc:A00*K10  + A01*K11  + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:A02  | W:K02  | Acc:A00*K00  + A01*K01  + A02*K02  + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['A03', 'A03', 'A03', 'A10']
# [A:A03  | W:K00  | Acc:A03*K00  + 0        + 0        + 0       ] | [A:A02  | W:K10  | Acc:A02*K10  + 0        + 0        + 0       ] | [A:A01  | W:K20  | Acc:A01*K20  + 0        + 0        + 0       ] | [A:A00  | W:K30  | Acc:A00*K30  + 0        + 0        + 0       ]
# [A:A03  | W:K01  | Acc:A02*K00  + A03*K01  + 0        + 0       ] | [A:A02  | W:K11  | Acc:A01*K10  + A02*K11  + 0        + 0       ] | [A:A01  | W:K21  | Acc:A00*K20  + A01*K21  + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:A03  | W:K02  | Acc:A01*K00  + A02*K01  + A03*K02  + 0       ] | [A:A02  | W:K12  | Acc:A00*K10  + A01*K11  + A02*K12  + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:A10  | W:K03  | Acc:A00*K00  + A01*K01  + A02*K02  + A10*K03 ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['A10', 'A04', 'A04', 'A11']
# [A:A10  | W:K00  | Acc:A10*K00  + 0        + 0        + 0       ] | [A:A03  | W:K10  | Acc:A03*K10  + 0        + 0        + 0       ] | [A:A02  | W:K20  | Acc:A02*K20  + 0        + 0        + 0       ] | [A:A01  | W:K30  | Acc:A01*K30  + 0        + 0        + 0       ]
# [A:A04  | W:K01  | Acc:A03*K00  + A04*K01  + 0        + 0       ] | [A:A03  | W:K11  | Acc:A02*K10  + A03*K11  + 0        + 0       ] | [A:A02  | W:K21  | Acc:A01*K20  + A02*K21  + 0        + 0       ] | [A:A01  | W:K31  | Acc:A00*K30  + A01*K31  + 0        + 0       ]
# [A:A04  | W:K02  | Acc:A02*K00  + A03*K01  + A04*K02  + 0       ] | [A:A03  | W:K12  | Acc:A01*K10  + A02*K11  + A03*K12  + 0       ] | [A:A02  | W:K22  | Acc:A00*K20  + A01*K21  + A02*K22  + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:A11  | W:K03  | Acc:A01*K00  + A02*K01  + A03*K02  + A11*K03 ] | [A:A10  | W:K13  | Acc:A00*K10  + A01*K11  + A02*K12  + A10*K13 ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['Cxx_x', '000_0', '000_0', '000_0']
#
# New activations: ['A11', 'A11', 'A05', 'A12']
# [A:A11  | W:K00  | Acc:A11*K00  + 0        + 0        + 0       ] | [A:A10  | W:K10  | Acc:A10*K10  + 0        + 0        + 0       ] | [A:A03  | W:K20  | Acc:A03*K20  + 0        + 0        + 0       ] | [A:A02  | W:K30  | Acc:A02*K30  + 0        + 0        + 0       ]
# [A:A11  | W:K01  | Acc:A10*K00  + A11*K01  + 0        + 0       ] | [A:A04  | W:K11  | Acc:A03*K10  + A04*K11  + 0        + 0       ] | [A:A03  | W:K21  | Acc:A02*K20  + A03*K21  + 0        + 0       ] | [A:A02  | W:K31  | Acc:A01*K30  + A02*K31  + 0        + 0       ]
# [A:A05  | W:K02  | Acc:A03*K00  + A04*K01  + A05*K02  + 0       ] | [A:A04  | W:K12  | Acc:A02*K10  + A03*K11  + A04*K12  + 0       ] | [A:A03  | W:K22  | Acc:A01*K20  + A02*K21  + A03*K22  + 0       ] | [A:A02  | W:K32  | Acc:A00*K30  + A01*K31  + A02*K32  + 0       ]
# [A:A12  | W:K03  | Acc:A02*K00  + A03*K01  + A04*K02  + A12*K03 ] | [A:A11  | W:K13  | Acc:A01*K10  + A02*K11  + A03*K12  + A11*K13 ] | [A:A10  | W:K23  | Acc:A00*K20  + A01*K21  + A02*K22  + A10*K23 ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['Cxx_x', 'Cxx_x', '000_0', '000_0']
#
# New activations: ['A12', 'A12', 'A12', 'A13']
# [A:A12  | W:K00  | Acc:A12*K00  + 0        + 0        + 0       ] | [A:A11  | W:K10  | Acc:A11*K10  + 0        + 0        + 0       ] | [A:A10  | W:K20  | Acc:A10*K20  + 0        + 0        + 0       ] | [A:A03  | W:K30  | Acc:A03*K30  + 0        + 0        + 0       ]
# [A:A12  | W:K01  | Acc:A11*K00  + A12*K01  + 0        + 0       ] | [A:A11  | W:K11  | Acc:A10*K10  + A11*K11  + 0        + 0       ] | [A:A04  | W:K21  | Acc:A03*K20  + A04*K21  + 0        + 0       ] | [A:A03  | W:K31  | Acc:A02*K30  + A03*K31  + 0        + 0       ]
# [A:A12  | W:K02  | Acc:A10*K00  + A11*K01  + A12*K02  + 0       ] | [A:A05  | W:K12  | Acc:A03*K10  + A04*K11  + A05*K12  + 0       ] | [A:A04  | W:K22  | Acc:A02*K20  + A03*K21  + A04*K22  + 0       ] | [A:A03  | W:K32  | Acc:A01*K30  + A02*K31  + A03*K32  + 0       ]
# [A:A13  | W:K03  | Acc:A03*K00  + A04*K01  + A05*K02  + A13*K03 ] | [A:A12  | W:K13  | Acc:A02*K10  + A03*K11  + A04*K12  + A12*K13 ] | [A:A11  | W:K23  | Acc:A01*K20  + A02*K21  + A03*K22  + A11*K23 ] | [A:A10  | W:K33  | Acc:A00*K30  + A01*K31  + A02*K32  + A10*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', '000_0']
#
# New activations: ['A13', 'A13', 'A13', 'A20']
# [A:A13  | W:K00  | Acc:A13*K00  + 0        + 0        + 0       ] | [A:A12  | W:K10  | Acc:A12*K10  + 0        + 0        + 0       ] | [A:A11  | W:K20  | Acc:A11*K20  + 0        + 0        + 0       ] | [A:A10  | W:K30  | Acc:A10*K30  + 0        + 0        + 0       ]
# [A:A13  | W:K01  | Acc:A12*K00  + A13*K01  + 0        + 0       ] | [A:A12  | W:K11  | Acc:A11*K10  + A12*K11  + 0        + 0       ] | [A:A11  | W:K21  | Acc:A10*K20  + A11*K21  + 0        + 0       ] | [A:A04  | W:K31  | Acc:A03*K30  + A04*K31  + 0        + 0       ]
# [A:A13  | W:K02  | Acc:A11*K00  + A12*K01  + A13*K02  + 0       ] | [A:A12  | W:K12  | Acc:A10*K10  + A11*K11  + A12*K12  + 0       ] | [A:A05  | W:K22  | Acc:A03*K20  + A04*K21  + A05*K22  + 0       ] | [A:A04  | W:K32  | Acc:A02*K30  + A03*K31  + A04*K32  + 0       ]
# [A:A20  | W:K03  | Acc:A10*K00  + A11*K01  + A12*K02  + A20*K03 ] | [A:A13  | W:K13  | Acc:A03*K10  + A04*K11  + A05*K12  + A13*K13 ] | [A:A12  | W:K23  | Acc:A02*K20  + A03*K21  + A04*K22  + A12*K23 ] | [A:A11  | W:K33  | Acc:A01*K30  + A02*K31  + A03*K32  + A11*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A20', 'A14', 'A14', 'A21']
# [A:A20  | W:K00  | Acc:A20*K00  + 0        + 0        + 0       ] | [A:A13  | W:K10  | Acc:A13*K10  + 0        + 0        + 0       ] | [A:A12  | W:K20  | Acc:A12*K20  + 0        + 0        + 0       ] | [A:A11  | W:K30  | Acc:A11*K30  + 0        + 0        + 0       ]
# [A:A14  | W:K01  | Acc:A13*K00  + A14*K01  + 0        + 0       ] | [A:A13  | W:K11  | Acc:A12*K10  + A13*K11  + 0        + 0       ] | [A:A12  | W:K21  | Acc:A11*K20  + A12*K21  + 0        + 0       ] | [A:A11  | W:K31  | Acc:A10*K30  + A11*K31  + 0        + 0       ]
# [A:A14  | W:K02  | Acc:A12*K00  + A13*K01  + A14*K02  + 0       ] | [A:A13  | W:K12  | Acc:A11*K10  + A12*K11  + A13*K12  + 0       ] | [A:A12  | W:K22  | Acc:A10*K20  + A11*K21  + A12*K22  + 0       ] | [A:A05  | W:K32  | Acc:A03*K30  + A04*K31  + A05*K32  + 0       ]
# [A:A21  | W:K03  | Acc:A11*K00  + A12*K01  + A13*K02  + A21*K03 ] | [A:A20  | W:K13  | Acc:A10*K10  + A11*K11  + A12*K12  + A20*K13 ] | [A:A13  | W:K23  | Acc:A03*K20  + A04*K21  + A05*K22  + A13*K23 ] | [A:A12  | W:K33  | Acc:A02*K30  + A03*K31  + A04*K32  + A12*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A21', 'A21', 'A15', 'A22']
# [A:A21  | W:K00  | Acc:A21*K00  + 0        + 0        + 0       ] | [A:A20  | W:K10  | Acc:A20*K10  + 0        + 0        + 0       ] | [A:A13  | W:K20  | Acc:A13*K20  + 0        + 0        + 0       ] | [A:A12  | W:K30  | Acc:A12*K30  + 0        + 0        + 0       ]
# [A:A21  | W:K01  | Acc:A20*K00  + A21*K01  + 0        + 0       ] | [A:A14  | W:K11  | Acc:A13*K10  + A14*K11  + 0        + 0       ] | [A:A13  | W:K21  | Acc:A12*K20  + A13*K21  + 0        + 0       ] | [A:A12  | W:K31  | Acc:A11*K30  + A12*K31  + 0        + 0       ]
# [A:A15  | W:K02  | Acc:A13*K00  + A14*K01  + A15*K02  + 0       ] | [A:A14  | W:K12  | Acc:A12*K10  + A13*K11  + A14*K12  + 0       ] | [A:A13  | W:K22  | Acc:A11*K20  + A12*K21  + A13*K22  + 0       ] | [A:A12  | W:K32  | Acc:A10*K30  + A11*K31  + A12*K32  + 0       ]
# [A:A22  | W:K03  | Acc:A12*K00  + A13*K01  + A14*K02  + A22*K03 ] | [A:A21  | W:K13  | Acc:A11*K10  + A12*K11  + A13*K12  + A21*K13 ] | [A:A20  | W:K23  | Acc:A10*K20  + A11*K21  + A12*K22  + A20*K23 ] | [A:A13  | W:K33  | Acc:A03*K30  + A04*K31  + A05*K32  + A13*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A22', 'A22', 'A22', 'A23']
# [A:A22  | W:K00  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A21  | W:K10  | Acc:A21*K10  + 0        + 0        + 0       ] | [A:A20  | W:K20  | Acc:A20*K20  + 0        + 0        + 0       ] | [A:A13  | W:K30  | Acc:A13*K30  + 0        + 0        + 0       ]
# [A:A22  | W:K01  | Acc:A21*K00  + A22*K01  + 0        + 0       ] | [A:A21  | W:K11  | Acc:A20*K10  + A21*K11  + 0        + 0       ] | [A:A14  | W:K21  | Acc:A13*K20  + A14*K21  + 0        + 0       ] | [A:A13  | W:K31  | Acc:A12*K30  + A13*K31  + 0        + 0       ]
# [A:A22  | W:K02  | Acc:A20*K00  + A21*K01  + A22*K02  + 0       ] | [A:A15  | W:K12  | Acc:A13*K10  + A14*K11  + A15*K12  + 0       ] | [A:A14  | W:K22  | Acc:A12*K20  + A13*K21  + A14*K22  + 0       ] | [A:A13  | W:K32  | Acc:A11*K30  + A12*K31  + A13*K32  + 0       ]
# [A:A23  | W:K03  | Acc:A13*K00  + A14*K01  + A15*K02  + A23*K03 ] | [A:A22  | W:K13  | Acc:A12*K10  + A13*K11  + A14*K12  + A22*K13 ] | [A:A21  | W:K23  | Acc:A11*K20  + A12*K21  + A13*K22  + A21*K23 ] | [A:A20  | W:K33  | Acc:A10*K30  + A11*K31  + A12*K32  + A20*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A23', 'A23', 'A23', 'A30']
# [A:A23  | W:K00  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:A22  | W:K10  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A21  | W:K20  | Acc:A21*K20  + 0        + 0        + 0       ] | [A:A20  | W:K30  | Acc:A20*K30  + 0        + 0        + 0       ]
# [A:A23  | W:K01  | Acc:A22*K00  + A23*K01  + 0        + 0       ] | [A:A22  | W:K11  | Acc:A21*K10  + A22*K11  + 0        + 0       ] | [A:A21  | W:K21  | Acc:A20*K20  + A21*K21  + 0        + 0       ] | [A:A14  | W:K31  | Acc:A13*K30  + A14*K31  + 0        + 0       ]
# [A:A23  | W:K02  | Acc:A21*K00  + A22*K01  + A23*K02  + 0       ] | [A:A22  | W:K12  | Acc:A20*K10  + A21*K11  + A22*K12  + 0       ] | [A:A15  | W:K22  | Acc:A13*K20  + A14*K21  + A15*K22  + 0       ] | [A:A14  | W:K32  | Acc:A12*K30  + A13*K31  + A14*K32  + 0       ]
# [A:A30  | W:K03  | Acc:A20*K00  + A21*K01  + A22*K02  + A30*K03 ] | [A:A23  | W:K13  | Acc:A13*K10  + A14*K11  + A15*K12  + A23*K13 ] | [A:A22  | W:K23  | Acc:A12*K20  + A13*K21  + A14*K22  + A22*K23 ] | [A:A21  | W:K33  | Acc:A11*K30  + A12*K31  + A13*K32  + A21*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A30', 'A24', 'A24', 'A31']
# [A:A30  | W:K00  | Acc:A30*K00  + 0        + 0        + 0       ] | [A:A23  | W:K10  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:A22  | W:K20  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A21  | W:K30  | Acc:A21*K30  + 0        + 0        + 0       ]
# [A:A24  | W:K01  | Acc:A23*K00  + A24*K01  + 0        + 0       ] | [A:A23  | W:K11  | Acc:A22*K10  + A23*K11  + 0        + 0       ] | [A:A22  | W:K21  | Acc:A21*K20  + A22*K21  + 0        + 0       ] | [A:A21  | W:K31  | Acc:A20*K30  + A21*K31  + 0        + 0       ]
# [A:A24  | W:K02  | Acc:A22*K00  + A23*K01  + A24*K02  + 0       ] | [A:A23  | W:K12  | Acc:A21*K10  + A22*K11  + A23*K12  + 0       ] | [A:A22  | W:K22  | Acc:A20*K20  + A21*K21  + A22*K22  + 0       ] | [A:A15  | W:K32  | Acc:A13*K30  + A14*K31  + A15*K32  + 0       ]
# [A:A31  | W:K03  | Acc:A21*K00  + A22*K01  + A23*K02  + A31*K03 ] | [A:A30  | W:K13  | Acc:A20*K10  + A21*K11  + A22*K12  + A30*K13 ] | [A:A23  | W:K23  | Acc:A13*K20  + A14*K21  + A15*K22  + A23*K23 ] | [A:A22  | W:K33  | Acc:A12*K30  + A13*K31  + A14*K32  + A22*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A31', 'A31', 'A25', 'A32']
# [A:A31  | W:K00  | Acc:A31*K00  + 0        + 0        + 0       ] | [A:A30  | W:K10  | Acc:A30*K10  + 0        + 0        + 0       ] | [A:A23  | W:K20  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:A22  | W:K30  | Acc:A22*K30  + 0        + 0        + 0       ]
# [A:A31  | W:K01  | Acc:A30*K00  + A31*K01  + 0        + 0       ] | [A:A24  | W:K11  | Acc:A23*K10  + A24*K11  + 0        + 0       ] | [A:A23  | W:K21  | Acc:A22*K20  + A23*K21  + 0        + 0       ] | [A:A22  | W:K31  | Acc:A21*K30  + A22*K31  + 0        + 0       ]
# [A:A25  | W:K02  | Acc:A23*K00  + A24*K01  + A25*K02  + 0       ] | [A:A24  | W:K12  | Acc:A22*K10  + A23*K11  + A24*K12  + 0       ] | [A:A23  | W:K22  | Acc:A21*K20  + A22*K21  + A23*K22  + 0       ] | [A:A22  | W:K32  | Acc:A20*K30  + A21*K31  + A22*K32  + 0       ]
# [A:A32  | W:K03  | Acc:A22*K00  + A23*K01  + A24*K02  + A32*K03 ] | [A:A31  | W:K13  | Acc:A21*K10  + A22*K11  + A23*K12  + A31*K13 ] | [A:A30  | W:K23  | Acc:A20*K20  + A21*K21  + A22*K22  + A30*K23 ] | [A:A23  | W:K33  | Acc:A13*K30  + A14*K31  + A15*K32  + A23*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A32', 'A32', 'A32', 'A33']
# [A:A32  | W:K00  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:A31  | W:K10  | Acc:A31*K10  + 0        + 0        + 0       ] | [A:A30  | W:K20  | Acc:A30*K20  + 0        + 0        + 0       ] | [A:A23  | W:K30  | Acc:A23*K30  + 0        + 0        + 0       ]
# [A:A32  | W:K01  | Acc:A31*K00  + A32*K01  + 0        + 0       ] | [A:A31  | W:K11  | Acc:A30*K10  + A31*K11  + 0        + 0       ] | [A:A24  | W:K21  | Acc:A23*K20  + A24*K21  + 0        + 0       ] | [A:A23  | W:K31  | Acc:A22*K30  + A23*K31  + 0        + 0       ]
# [A:A32  | W:K02  | Acc:A30*K00  + A31*K01  + A32*K02  + 0       ] | [A:A25  | W:K12  | Acc:A23*K10  + A24*K11  + A25*K12  + 0       ] | [A:A24  | W:K22  | Acc:A22*K20  + A23*K21  + A24*K22  + 0       ] | [A:A23  | W:K32  | Acc:A21*K30  + A22*K31  + A23*K32  + 0       ]
# [A:A33  | W:K03  | Acc:A23*K00  + A24*K01  + A25*K02  + A33*K03 ] | [A:A32  | W:K13  | Acc:A22*K10  + A23*K11  + A24*K12  + A32*K13 ] | [A:A31  | W:K23  | Acc:A21*K20  + A22*K21  + A23*K22  + A31*K23 ] | [A:A30  | W:K33  | Acc:A20*K30  + A21*K31  + A22*K32  + A30*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A33', 'A33', 'A33', 'A40']
# [A:A33  | W:K00  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:A32  | W:K10  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:A31  | W:K20  | Acc:A31*K20  + 0        + 0        + 0       ] | [A:A30  | W:K30  | Acc:A30*K30  + 0        + 0        + 0       ]
# [A:A33  | W:K01  | Acc:A32*K00  + A33*K01  + 0        + 0       ] | [A:A32  | W:K11  | Acc:A31*K10  + A32*K11  + 0        + 0       ] | [A:A31  | W:K21  | Acc:A30*K20  + A31*K21  + 0        + 0       ] | [A:A24  | W:K31  | Acc:A23*K30  + A24*K31  + 0        + 0       ]
# [A:A33  | W:K02  | Acc:A31*K00  + A32*K01  + A33*K02  + 0       ] | [A:A32  | W:K12  | Acc:A30*K10  + A31*K11  + A32*K12  + 0       ] | [A:A25  | W:K22  | Acc:A23*K20  + A24*K21  + A25*K22  + 0       ] | [A:A24  | W:K32  | Acc:A22*K30  + A23*K31  + A24*K32  + 0       ]
# [A:A40  | W:K03  | Acc:A30*K00  + A31*K01  + A32*K02  + A40*K03 ] | [A:A33  | W:K13  | Acc:A23*K10  + A24*K11  + A25*K12  + A33*K13 ] | [A:A32  | W:K23  | Acc:A22*K20  + A23*K21  + A24*K22  + A32*K23 ] | [A:A31  | W:K33  | Acc:A21*K30  + A22*K31  + A23*K32  + A31*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A11', 'A34', 'A34', 'A41']
# [A:A11  | W:K00  | Acc:A11*K00  + 0        + 0        + 0       ] | [A:A33  | W:K10  | Acc:A33*K10  + 0        + 0        + 0       ] | [A:A32  | W:K20  | Acc:A32*K20  + 0        + 0        + 0       ] | [A:A31  | W:K30  | Acc:A31*K30  + 0        + 0        + 0       ]
# [A:A34  | W:K01  | Acc:A33*K00  + A34*K01  + 0        + 0       ] | [A:A33  | W:K11  | Acc:A32*K10  + A33*K11  + 0        + 0       ] | [A:A32  | W:K21  | Acc:A31*K20  + A32*K21  + 0        + 0       ] | [A:A31  | W:K31  | Acc:A30*K30  + A31*K31  + 0        + 0       ]
# [A:A34  | W:K02  | Acc:A32*K00  + A33*K01  + A34*K02  + 0       ] | [A:A33  | W:K12  | Acc:A31*K10  + A32*K11  + A33*K12  + 0       ] | [A:A32  | W:K22  | Acc:A30*K20  + A31*K21  + A32*K22  + 0       ] | [A:A25  | W:K32  | Acc:A23*K30  + A24*K31  + A25*K32  + 0       ]
# [A:A41  | W:K03  | Acc:A31*K00  + A32*K01  + A33*K02  + A41*K03 ] | [A:A40  | W:K13  | Acc:A30*K10  + A31*K11  + A32*K12  + A40*K13 ] | [A:A33  | W:K23  | Acc:A23*K20  + A24*K21  + A25*K22  + A33*K23 ] | [A:A32  | W:K33  | Acc:A22*K30  + A23*K31  + A24*K32  + A32*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A12', 'A12', 'A35', 'A42']
# [A:A12  | W:K00  | Acc:A12*K00  + 0        + 0        + 0       ] | [A:A11  | W:K10  | Acc:A11*K10  + 0        + 0        + 0       ] | [A:A33  | W:K20  | Acc:A33*K20  + 0        + 0        + 0       ] | [A:A32  | W:K30  | Acc:A32*K30  + 0        + 0        + 0       ]
# [A:A12  | W:K01  | Acc:A11*K00  + A12*K01  + 0        + 0       ] | [A:A34  | W:K11  | Acc:A33*K10  + A34*K11  + 0        + 0       ] | [A:A33  | W:K21  | Acc:A32*K20  + A33*K21  + 0        + 0       ] | [A:A32  | W:K31  | Acc:A31*K30  + A32*K31  + 0        + 0       ]
# [A:A35  | W:K02  | Acc:A33*K00  + A34*K01  + A35*K02  + 0       ] | [A:A34  | W:K12  | Acc:A32*K10  + A33*K11  + A34*K12  + 0       ] | [A:A33  | W:K22  | Acc:A31*K20  + A32*K21  + A33*K22  + 0       ] | [A:A32  | W:K32  | Acc:A30*K30  + A31*K31  + A32*K32  + 0       ]
# [A:A42  | W:K03  | Acc:A32*K00  + A33*K01  + A34*K02  + A42*K03 ] | [A:A41  | W:K13  | Acc:A31*K10  + A32*K11  + A33*K12  + A41*K13 ] | [A:A40  | W:K23  | Acc:A30*K20  + A31*K21  + A32*K22  + A40*K23 ] | [A:A33  | W:K33  | Acc:A23*K30  + A24*K31  + A25*K32  + A33*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A13', 'A13', 'A20', 'A43']
# [A:A13  | W:K00  | Acc:A13*K00  + 0        + 0        + 0       ] | [A:A12  | W:K10  | Acc:A12*K10  + 0        + 0        + 0       ] | [A:A11  | W:K20  | Acc:A11*K20  + 0        + 0        + 0       ] | [A:A33  | W:K30  | Acc:A33*K30  + 0        + 0        + 0       ]
# [A:A13  | W:K01  | Acc:A12*K00  + A13*K01  + 0        + 0       ] | [A:A12  | W:K11  | Acc:A11*K10  + A12*K11  + 0        + 0       ] | [A:A34  | W:K21  | Acc:A33*K20  + A34*K21  + 0        + 0       ] | [A:A33  | W:K31  | Acc:A32*K30  + A33*K31  + 0        + 0       ]
# [A:A20  | W:K02  | Acc:A11*K00  + A12*K01  + A20*K02  + 0       ] | [A:A35  | W:K12  | Acc:A33*K10  + A34*K11  + A35*K12  + 0       ] | [A:A34  | W:K22  | Acc:A32*K20  + A33*K21  + A34*K22  + 0       ] | [A:A33  | W:K32  | Acc:A31*K30  + A32*K31  + A33*K32  + 0       ]
# [A:A43  | W:K03  | Acc:A33*K00  + A34*K01  + A35*K02  + A43*K03 ] | [A:A42  | W:K13  | Acc:A32*K10  + A33*K11  + A34*K12  + A42*K13 ] | [A:A41  | W:K23  | Acc:A31*K20  + A32*K21  + A33*K22  + A41*K23 ] | [A:A40  | W:K33  | Acc:A30*K30  + A31*K31  + A32*K32  + A40*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A14', 'A14', 'A21', 'A21']
# [A:A14  | W:K00  | Acc:A14*K00  + 0        + 0        + 0       ] | [A:A13  | W:K10  | Acc:A13*K10  + 0        + 0        + 0       ] | [A:A12  | W:K20  | Acc:A12*K20  + 0        + 0        + 0       ] | [A:A11  | W:K30  | Acc:A11*K30  + 0        + 0        + 0       ]
# [A:A14  | W:K01  | Acc:A13*K00  + A14*K01  + 0        + 0       ] | [A:A13  | W:K11  | Acc:A12*K10  + A13*K11  + 0        + 0       ] | [A:A12  | W:K21  | Acc:A11*K20  + A12*K21  + 0        + 0       ] | [A:A34  | W:K31  | Acc:A33*K30  + A34*K31  + 0        + 0       ]
# [A:A21  | W:K02  | Acc:A12*K00  + A13*K01  + A21*K02  + 0       ] | [A:A20  | W:K12  | Acc:A11*K10  + A12*K11  + A20*K12  + 0       ] | [A:A35  | W:K22  | Acc:A33*K20  + A34*K21  + A35*K22  + 0       ] | [A:A34  | W:K32  | Acc:A32*K30  + A33*K31  + A34*K32  + 0       ]
# [A:A21  | W:K03  | Acc:A11*K00  + A12*K01  + A20*K02  + A21*K03 ] | [A:A43  | W:K13  | Acc:A33*K10  + A34*K11  + A35*K12  + A43*K13 ] | [A:A42  | W:K23  | Acc:A32*K20  + A33*K21  + A34*K22  + A42*K23 ] | [A:A41  | W:K33  | Acc:A31*K30  + A32*K31  + A33*K32  + A41*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A21', 'A15', 'A22', 'A22']
# [A:A21  | W:K00  | Acc:A21*K00  + 0        + 0        + 0       ] | [A:A14  | W:K10  | Acc:A14*K10  + 0        + 0        + 0       ] | [A:A13  | W:K20  | Acc:A13*K20  + 0        + 0        + 0       ] | [A:A12  | W:K30  | Acc:A12*K30  + 0        + 0        + 0       ]
# [A:A15  | W:K01  | Acc:A14*K00  + A15*K01  + 0        + 0       ] | [A:A14  | W:K11  | Acc:A13*K10  + A14*K11  + 0        + 0       ] | [A:A13  | W:K21  | Acc:A12*K20  + A13*K21  + 0        + 0       ] | [A:A12  | W:K31  | Acc:A11*K30  + A12*K31  + 0        + 0       ]
# [A:A22  | W:K02  | Acc:A13*K00  + A14*K01  + A22*K02  + 0       ] | [A:A21  | W:K12  | Acc:A12*K10  + A13*K11  + A21*K12  + 0       ] | [A:A20  | W:K22  | Acc:A11*K20  + A12*K21  + A20*K22  + 0       ] | [A:A35  | W:K32  | Acc:A33*K30  + A34*K31  + A35*K32  + 0       ]
# [A:A22  | W:K03  | Acc:A12*K00  + A13*K01  + A21*K02  + A22*K03 ] | [A:A21  | W:K13  | Acc:A11*K10  + A12*K11  + A20*K12  + A21*K13 ] | [A:A43  | W:K23  | Acc:A33*K20  + A34*K21  + A35*K22  + A43*K23 ] | [A:A42  | W:K33  | Acc:A32*K30  + A33*K31  + A34*K32  + A42*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A22', 'A22', 'A23', 'A23']
# [A:A22  | W:K00  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A21  | W:K10  | Acc:A21*K10  + 0        + 0        + 0       ] | [A:A14  | W:K20  | Acc:A14*K20  + 0        + 0        + 0       ] | [A:A13  | W:K30  | Acc:A13*K30  + 0        + 0        + 0       ]
# [A:A22  | W:K01  | Acc:A21*K00  + A22*K01  + 0        + 0       ] | [A:A15  | W:K11  | Acc:A14*K10  + A15*K11  + 0        + 0       ] | [A:A14  | W:K21  | Acc:A13*K20  + A14*K21  + 0        + 0       ] | [A:A13  | W:K31  | Acc:A12*K30  + A13*K31  + 0        + 0       ]
# [A:A23  | W:K02  | Acc:A14*K00  + A15*K01  + A23*K02  + 0       ] | [A:A22  | W:K12  | Acc:A13*K10  + A14*K11  + A22*K12  + 0       ] | [A:A21  | W:K22  | Acc:A12*K20  + A13*K21  + A21*K22  + 0       ] | [A:A20  | W:K32  | Acc:A11*K30  + A12*K31  + A20*K32  + 0       ]
# [A:A23  | W:K03  | Acc:A13*K00  + A14*K01  + A22*K02  + A23*K03 ] | [A:A22  | W:K13  | Acc:A12*K10  + A13*K11  + A21*K12  + A22*K13 ] | [A:A21  | W:K23  | Acc:A11*K20  + A12*K21  + A20*K22  + A21*K23 ] | [A:A43  | W:K33  | Acc:A33*K30  + A34*K31  + A35*K32  + A43*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A23', 'A23', 'A30', 'A24']
# [A:A23  | W:K00  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:A22  | W:K10  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A21  | W:K20  | Acc:A21*K20  + 0        + 0        + 0       ] | [A:A14  | W:K30  | Acc:A14*K30  + 0        + 0        + 0       ]
# [A:A23  | W:K01  | Acc:A22*K00  + A23*K01  + 0        + 0       ] | [A:A22  | W:K11  | Acc:A21*K10  + A22*K11  + 0        + 0       ] | [A:A15  | W:K21  | Acc:A14*K20  + A15*K21  + 0        + 0       ] | [A:A14  | W:K31  | Acc:A13*K30  + A14*K31  + 0        + 0       ]
# [A:A30  | W:K02  | Acc:A21*K00  + A22*K01  + A30*K02  + 0       ] | [A:A23  | W:K12  | Acc:A14*K10  + A15*K11  + A23*K12  + 0       ] | [A:A22  | W:K22  | Acc:A13*K20  + A14*K21  + A22*K22  + 0       ] | [A:A21  | W:K32  | Acc:A12*K30  + A13*K31  + A21*K32  + 0       ]
# [A:A24  | W:K03  | Acc:A14*K00  + A15*K01  + A23*K02  + A24*K03 ] | [A:A23  | W:K13  | Acc:A13*K10  + A14*K11  + A22*K12  + A23*K13 ] | [A:A22  | W:K23  | Acc:A12*K20  + A13*K21  + A21*K22  + A22*K23 ] | [A:A21  | W:K33  | Acc:A11*K30  + A12*K31  + A20*K32  + A21*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A24', 'A24', 'A31', 'A31']
# [A:A24  | W:K00  | Acc:A24*K00  + 0        + 0        + 0       ] | [A:A23  | W:K10  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:A22  | W:K20  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A21  | W:K30  | Acc:A21*K30  + 0        + 0        + 0       ]
# [A:A24  | W:K01  | Acc:A23*K00  + A24*K01  + 0        + 0       ] | [A:A23  | W:K11  | Acc:A22*K10  + A23*K11  + 0        + 0       ] | [A:A22  | W:K21  | Acc:A21*K20  + A22*K21  + 0        + 0       ] | [A:A15  | W:K31  | Acc:A14*K30  + A15*K31  + 0        + 0       ]
# [A:A31  | W:K02  | Acc:A22*K00  + A23*K01  + A31*K02  + 0       ] | [A:A30  | W:K12  | Acc:A21*K10  + A22*K11  + A30*K12  + 0       ] | [A:A23  | W:K22  | Acc:A14*K20  + A15*K21  + A23*K22  + 0       ] | [A:A22  | W:K32  | Acc:A13*K30  + A14*K31  + A22*K32  + 0       ]
# [A:A31  | W:K03  | Acc:A21*K00  + A22*K01  + A30*K02  + A31*K03 ] | [A:A24  | W:K13  | Acc:A14*K10  + A15*K11  + A23*K12  + A24*K13 ] | [A:A23  | W:K23  | Acc:A13*K20  + A14*K21  + A22*K22  + A23*K23 ] | [A:A22  | W:K33  | Acc:A12*K30  + A13*K31  + A21*K32  + A22*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A31', 'A25', 'A32', 'A32']
# [A:A31  | W:K00  | Acc:A31*K00  + 0        + 0        + 0       ] | [A:A24  | W:K10  | Acc:A24*K10  + 0        + 0        + 0       ] | [A:A23  | W:K20  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:A22  | W:K30  | Acc:A22*K30  + 0        + 0        + 0       ]
# [A:A25  | W:K01  | Acc:A24*K00  + A25*K01  + 0        + 0       ] | [A:A24  | W:K11  | Acc:A23*K10  + A24*K11  + 0        + 0       ] | [A:A23  | W:K21  | Acc:A22*K20  + A23*K21  + 0        + 0       ] | [A:A22  | W:K31  | Acc:A21*K30  + A22*K31  + 0        + 0       ]
# [A:A32  | W:K02  | Acc:A23*K00  + A24*K01  + A32*K02  + 0       ] | [A:A31  | W:K12  | Acc:A22*K10  + A23*K11  + A31*K12  + 0       ] | [A:A30  | W:K22  | Acc:A21*K20  + A22*K21  + A30*K22  + 0       ] | [A:A23  | W:K32  | Acc:A14*K30  + A15*K31  + A23*K32  + 0       ]
# [A:A32  | W:K03  | Acc:A22*K00  + A23*K01  + A31*K02  + A32*K03 ] | [A:A31  | W:K13  | Acc:A21*K10  + A22*K11  + A30*K12  + A31*K13 ] | [A:A24  | W:K23  | Acc:A14*K20  + A15*K21  + A23*K22  + A24*K23 ] | [A:A23  | W:K33  | Acc:A13*K30  + A14*K31  + A22*K32  + A23*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A32', 'A32', 'A33', 'A33']
# [A:A32  | W:K00  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:A31  | W:K10  | Acc:A31*K10  + 0        + 0        + 0       ] | [A:A24  | W:K20  | Acc:A24*K20  + 0        + 0        + 0       ] | [A:A23  | W:K30  | Acc:A23*K30  + 0        + 0        + 0       ]
# [A:A32  | W:K01  | Acc:A31*K00  + A32*K01  + 0        + 0       ] | [A:A25  | W:K11  | Acc:A24*K10  + A25*K11  + 0        + 0       ] | [A:A24  | W:K21  | Acc:A23*K20  + A24*K21  + 0        + 0       ] | [A:A23  | W:K31  | Acc:A22*K30  + A23*K31  + 0        + 0       ]
# [A:A33  | W:K02  | Acc:A24*K00  + A25*K01  + A33*K02  + 0       ] | [A:A32  | W:K12  | Acc:A23*K10  + A24*K11  + A32*K12  + 0       ] | [A:A31  | W:K22  | Acc:A22*K20  + A23*K21  + A31*K22  + 0       ] | [A:A30  | W:K32  | Acc:A21*K30  + A22*K31  + A30*K32  + 0       ]
# [A:A33  | W:K03  | Acc:A23*K00  + A24*K01  + A32*K02  + A33*K03 ] | [A:A32  | W:K13  | Acc:A22*K10  + A23*K11  + A31*K12  + A32*K13 ] | [A:A31  | W:K23  | Acc:A21*K20  + A22*K21  + A30*K22  + A31*K23 ] | [A:A24  | W:K33  | Acc:A14*K30  + A15*K31  + A23*K32  + A24*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A33', 'A33', 'A40', 'A34']
# [A:A33  | W:K00  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:A32  | W:K10  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:A31  | W:K20  | Acc:A31*K20  + 0        + 0        + 0       ] | [A:A24  | W:K30  | Acc:A24*K30  + 0        + 0        + 0       ]
# [A:A33  | W:K01  | Acc:A32*K00  + A33*K01  + 0        + 0       ] | [A:A32  | W:K11  | Acc:A31*K10  + A32*K11  + 0        + 0       ] | [A:A25  | W:K21  | Acc:A24*K20  + A25*K21  + 0        + 0       ] | [A:A24  | W:K31  | Acc:A23*K30  + A24*K31  + 0        + 0       ]
# [A:A40  | W:K02  | Acc:A31*K00  + A32*K01  + A40*K02  + 0       ] | [A:A33  | W:K12  | Acc:A24*K10  + A25*K11  + A33*K12  + 0       ] | [A:A32  | W:K22  | Acc:A23*K20  + A24*K21  + A32*K22  + 0       ] | [A:A31  | W:K32  | Acc:A22*K30  + A23*K31  + A31*K32  + 0       ]
# [A:A34  | W:K03  | Acc:A24*K00  + A25*K01  + A33*K02  + A34*K03 ] | [A:A33  | W:K13  | Acc:A23*K10  + A24*K11  + A32*K12  + A33*K13 ] | [A:A32  | W:K23  | Acc:A22*K20  + A23*K21  + A31*K22  + A32*K23 ] | [A:A31  | W:K33  | Acc:A21*K30  + A22*K31  + A30*K32  + A31*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A34', 'A34', 'A41', 'A41']
# [A:A34  | W:K00  | Acc:A34*K00  + 0        + 0        + 0       ] | [A:A33  | W:K10  | Acc:A33*K10  + 0        + 0        + 0       ] | [A:A32  | W:K20  | Acc:A32*K20  + 0        + 0        + 0       ] | [A:A31  | W:K30  | Acc:A31*K30  + 0        + 0        + 0       ]
# [A:A34  | W:K01  | Acc:A33*K00  + A34*K01  + 0        + 0       ] | [A:A33  | W:K11  | Acc:A32*K10  + A33*K11  + 0        + 0       ] | [A:A32  | W:K21  | Acc:A31*K20  + A32*K21  + 0        + 0       ] | [A:A25  | W:K31  | Acc:A24*K30  + A25*K31  + 0        + 0       ]
# [A:A41  | W:K02  | Acc:A32*K00  + A33*K01  + A41*K02  + 0       ] | [A:A40  | W:K12  | Acc:A31*K10  + A32*K11  + A40*K12  + 0       ] | [A:A33  | W:K22  | Acc:A24*K20  + A25*K21  + A33*K22  + 0       ] | [A:A32  | W:K32  | Acc:A23*K30  + A24*K31  + A32*K32  + 0       ]
# [A:A41  | W:K03  | Acc:A31*K00  + A32*K01  + A40*K02  + A41*K03 ] | [A:A34  | W:K13  | Acc:A24*K10  + A25*K11  + A33*K12  + A34*K13 ] | [A:A33  | W:K23  | Acc:A23*K20  + A24*K21  + A32*K22  + A33*K23 ] | [A:A32  | W:K33  | Acc:A22*K30  + A23*K31  + A31*K32  + A32*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A41', 'A35', 'A42', 'A42']
# [A:A41  | W:K00  | Acc:A41*K00  + 0        + 0        + 0       ] | [A:A34  | W:K10  | Acc:A34*K10  + 0        + 0        + 0       ] | [A:A33  | W:K20  | Acc:A33*K20  + 0        + 0        + 0       ] | [A:A32  | W:K30  | Acc:A32*K30  + 0        + 0        + 0       ]
# [A:A35  | W:K01  | Acc:A34*K00  + A35*K01  + 0        + 0       ] | [A:A34  | W:K11  | Acc:A33*K10  + A34*K11  + 0        + 0       ] | [A:A33  | W:K21  | Acc:A32*K20  + A33*K21  + 0        + 0       ] | [A:A32  | W:K31  | Acc:A31*K30  + A32*K31  + 0        + 0       ]
# [A:A42  | W:K02  | Acc:A33*K00  + A34*K01  + A42*K02  + 0       ] | [A:A41  | W:K12  | Acc:A32*K10  + A33*K11  + A41*K12  + 0       ] | [A:A40  | W:K22  | Acc:A31*K20  + A32*K21  + A40*K22  + 0       ] | [A:A33  | W:K32  | Acc:A24*K30  + A25*K31  + A33*K32  + 0       ]
# [A:A42  | W:K03  | Acc:A32*K00  + A33*K01  + A41*K02  + A42*K03 ] | [A:A41  | W:K13  | Acc:A31*K10  + A32*K11  + A40*K12  + A41*K13 ] | [A:A34  | W:K23  | Acc:A24*K20  + A25*K21  + A33*K22  + A34*K23 ] | [A:A33  | W:K33  | Acc:A23*K30  + A24*K31  + A32*K32  + A33*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A42', 'A42', 'A43', 'A43']
# [A:A42  | W:K00  | Acc:A42*K00  + 0        + 0        + 0       ] | [A:A41  | W:K10  | Acc:A41*K10  + 0        + 0        + 0       ] | [A:A34  | W:K20  | Acc:A34*K20  + 0        + 0        + 0       ] | [A:A33  | W:K30  | Acc:A33*K30  + 0        + 0        + 0       ]
# [A:A42  | W:K01  | Acc:A41*K00  + A42*K01  + 0        + 0       ] | [A:A35  | W:K11  | Acc:A34*K10  + A35*K11  + 0        + 0       ] | [A:A34  | W:K21  | Acc:A33*K20  + A34*K21  + 0        + 0       ] | [A:A33  | W:K31  | Acc:A32*K30  + A33*K31  + 0        + 0       ]
# [A:A43  | W:K02  | Acc:A34*K00  + A35*K01  + A43*K02  + 0       ] | [A:A42  | W:K12  | Acc:A33*K10  + A34*K11  + A42*K12  + 0       ] | [A:A41  | W:K22  | Acc:A32*K20  + A33*K21  + A41*K22  + 0       ] | [A:A40  | W:K32  | Acc:A31*K30  + A32*K31  + A40*K32  + 0       ]
# [A:A43  | W:K03  | Acc:A33*K00  + A34*K01  + A42*K02  + A43*K03 ] | [A:A42  | W:K13  | Acc:A32*K10  + A33*K11  + A41*K12  + A42*K13 ] | [A:A41  | W:K23  | Acc:A31*K20  + A32*K21  + A40*K22  + A41*K23 ] | [A:A34  | W:K33  | Acc:A24*K30  + A25*K31  + A33*K32  + A34*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A43', 'A43', 'A50', 'A44']
# [A:A43  | W:K00  | Acc:A43*K00  + 0        + 0        + 0       ] | [A:A42  | W:K10  | Acc:A42*K10  + 0        + 0        + 0       ] | [A:A41  | W:K20  | Acc:A41*K20  + 0        + 0        + 0       ] | [A:A34  | W:K30  | Acc:A34*K30  + 0        + 0        + 0       ]
# [A:A43  | W:K01  | Acc:A42*K00  + A43*K01  + 0        + 0       ] | [A:A42  | W:K11  | Acc:A41*K10  + A42*K11  + 0        + 0       ] | [A:A35  | W:K21  | Acc:A34*K20  + A35*K21  + 0        + 0       ] | [A:A34  | W:K31  | Acc:A33*K30  + A34*K31  + 0        + 0       ]
# [A:A50  | W:K02  | Acc:A41*K00  + A42*K01  + A50*K02  + 0       ] | [A:A43  | W:K12  | Acc:A34*K10  + A35*K11  + A43*K12  + 0       ] | [A:A42  | W:K22  | Acc:A33*K20  + A34*K21  + A42*K22  + 0       ] | [A:A41  | W:K32  | Acc:A32*K30  + A33*K31  + A41*K32  + 0       ]
# [A:A44  | W:K03  | Acc:A34*K00  + A35*K01  + A43*K02  + A44*K03 ] | [A:A43  | W:K13  | Acc:A33*K10  + A34*K11  + A42*K12  + A43*K13 ] | [A:A42  | W:K23  | Acc:A32*K20  + A33*K21  + A41*K22  + A42*K23 ] | [A:A41  | W:K33  | Acc:A31*K30  + A32*K31  + A40*K32  + A41*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A44', 'A44', 'A51', 'A51']
# [A:A44  | W:K00  | Acc:A44*K00  + 0        + 0        + 0       ] | [A:A43  | W:K10  | Acc:A43*K10  + 0        + 0        + 0       ] | [A:A42  | W:K20  | Acc:A42*K20  + 0        + 0        + 0       ] | [A:A41  | W:K30  | Acc:A41*K30  + 0        + 0        + 0       ]
# [A:A44  | W:K01  | Acc:A43*K00  + A44*K01  + 0        + 0       ] | [A:A43  | W:K11  | Acc:A42*K10  + A43*K11  + 0        + 0       ] | [A:A42  | W:K21  | Acc:A41*K20  + A42*K21  + 0        + 0       ] | [A:A35  | W:K31  | Acc:A34*K30  + A35*K31  + 0        + 0       ]
# [A:A51  | W:K02  | Acc:A42*K00  + A43*K01  + A51*K02  + 0       ] | [A:A50  | W:K12  | Acc:A41*K10  + A42*K11  + A50*K12  + 0       ] | [A:A43  | W:K22  | Acc:A34*K20  + A35*K21  + A43*K22  + 0       ] | [A:A42  | W:K32  | Acc:A33*K30  + A34*K31  + A42*K32  + 0       ]
# [A:A51  | W:K03  | Acc:A41*K00  + A42*K01  + A50*K02  + A51*K03 ] | [A:A44  | W:K13  | Acc:A34*K10  + A35*K11  + A43*K12  + A44*K13 ] | [A:A43  | W:K23  | Acc:A33*K20  + A34*K21  + A42*K22  + A43*K23 ] | [A:A42  | W:K33  | Acc:A32*K30  + A33*K31  + A41*K32  + A42*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A22', 'A45', 'A52', 'A52']
# [A:A22  | W:K00  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A44  | W:K10  | Acc:A44*K10  + 0        + 0        + 0       ] | [A:A43  | W:K20  | Acc:A43*K20  + 0        + 0        + 0       ] | [A:A42  | W:K30  | Acc:A42*K30  + 0        + 0        + 0       ]
# [A:A45  | W:K01  | Acc:A44*K00  + A45*K01  + 0        + 0       ] | [A:A44  | W:K11  | Acc:A43*K10  + A44*K11  + 0        + 0       ] | [A:A43  | W:K21  | Acc:A42*K20  + A43*K21  + 0        + 0       ] | [A:A42  | W:K31  | Acc:A41*K30  + A42*K31  + 0        + 0       ]
# [A:A52  | W:K02  | Acc:A43*K00  + A44*K01  + A52*K02  + 0       ] | [A:A51  | W:K12  | Acc:A42*K10  + A43*K11  + A51*K12  + 0       ] | [A:A50  | W:K22  | Acc:A41*K20  + A42*K21  + A50*K22  + 0       ] | [A:A43  | W:K32  | Acc:A34*K30  + A35*K31  + A43*K32  + 0       ]
# [A:A52  | W:K03  | Acc:A42*K00  + A43*K01  + A51*K02  + A52*K03 ] | [A:A51  | W:K13  | Acc:A41*K10  + A42*K11  + A50*K12  + A51*K13 ] | [A:A44  | W:K23  | Acc:A34*K20  + A35*K21  + A43*K22  + A44*K23 ] | [A:A43  | W:K33  | Acc:A33*K30  + A34*K31  + A42*K32  + A43*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A23', '0', 'A53', 'A53']
# [A:A23  | W:K00  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:A22  | W:K10  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A44  | W:K20  | Acc:A44*K20  + 0        + 0        + 0       ] | [A:A43  | W:K30  | Acc:A43*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A45  | W:K11  | Acc:A44*K10  + A45*K11  + 0        + 0       ] | [A:A44  | W:K21  | Acc:A43*K20  + A44*K21  + 0        + 0       ] | [A:A43  | W:K31  | Acc:A42*K30  + A43*K31  + 0        + 0       ]
# [A:A53  | W:K02  | Acc:A44*K00  + A45*K01  + A53*K02  + 0       ] | [A:A52  | W:K12  | Acc:A43*K10  + A44*K11  + A52*K12  + 0       ] | [A:A51  | W:K22  | Acc:A42*K20  + A43*K21  + A51*K22  + 0       ] | [A:A50  | W:K32  | Acc:A41*K30  + A42*K31  + A50*K32  + 0       ]
# [A:A53  | W:K03  | Acc:A43*K00  + A44*K01  + A52*K02  + A53*K03 ] | [A:A52  | W:K13  | Acc:A42*K10  + A43*K11  + A51*K12  + A52*K13 ] | [A:A51  | W:K23  | Acc:A41*K20  + A42*K21  + A50*K22  + A51*K23 ] | [A:A44  | W:K33  | Acc:A34*K30  + A35*K31  + A43*K32  + A44*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A24', '0', '0', 'A54']
# [A:A24  | W:K00  | Acc:A24*K00  + 0        + 0        + 0       ] | [A:A23  | W:K10  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:A22  | W:K20  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A44  | W:K30  | Acc:A44*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A45  | W:K21  | Acc:A44*K20  + A45*K21  + 0        + 0       ] | [A:A44  | W:K31  | Acc:A43*K30  + A44*K31  + 0        + 0       ]
# [A:0    | W:K02  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A53  | W:K12  | Acc:A44*K10  + A45*K11  + A53*K12  + 0       ] | [A:A52  | W:K22  | Acc:A43*K20  + A44*K21  + A52*K22  + 0       ] | [A:A51  | W:K32  | Acc:A42*K30  + A43*K31  + A51*K32  + 0       ]
# [A:A54  | W:K03  | Acc:A44*K00  + A45*K01  + A53*K02  + A54*K03 ] | [A:A53  | W:K13  | Acc:A43*K10  + A44*K11  + A52*K12  + A53*K13 ] | [A:A52  | W:K23  | Acc:A42*K20  + A43*K21  + A51*K22  + A52*K23 ] | [A:A51  | W:K33  | Acc:A41*K30  + A42*K31  + A50*K32  + A51*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A25', '0', '0', '0']
# [A:A25  | W:K00  | Acc:A25*K00  + 0        + 0        + 0       ] | [A:A24  | W:K10  | Acc:A24*K10  + 0        + 0        + 0       ] | [A:A23  | W:K20  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:A22  | W:K30  | Acc:A22*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A24*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A45  | W:K31  | Acc:A44*K30  + A45*K31  + 0        + 0       ]
# [A:0    | W:K02  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A53  | W:K22  | Acc:A44*K20  + A45*K21  + A53*K22  + 0       ] | [A:A52  | W:K32  | Acc:A43*K30  + A44*K31  + A52*K32  + 0       ]
# [A:0    | W:K03  | Acc:A22*K00  + 0        + 0        + 0       ] | [A:A54  | W:K13  | Acc:A44*K10  + A45*K11  + A53*K12  + A54*K13 ] | [A:A53  | W:K23  | Acc:A43*K20  + A44*K21  + A52*K22  + A53*K23 ] | [A:A52  | W:K33  | Acc:A42*K30  + A43*K31  + A51*K32  + A52*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A32', '0', '0', '0']
# [A:A32  | W:K00  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:A25  | W:K10  | Acc:A25*K10  + 0        + 0        + 0       ] | [A:A24  | W:K20  | Acc:A24*K20  + 0        + 0        + 0       ] | [A:A23  | W:K30  | Acc:A23*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A25*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A24*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:A22*K30  + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:A24*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A53  | W:K32  | Acc:A44*K30  + A45*K31  + A53*K32  + 0       ]
# [A:0    | W:K03  | Acc:A23*K00  + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:A22*K10  + 0        + 0        + 0       ] | [A:A54  | W:K23  | Acc:A44*K20  + A45*K21  + A53*K22  + A54*K23 ] | [A:A53  | W:K33  | Acc:A43*K30  + A44*K31  + A52*K32  + A53*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A33', '0', '0', '0']
# [A:A33  | W:K00  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:A32  | W:K10  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:A25  | W:K20  | Acc:A25*K20  + 0        + 0        + 0       ] | [A:A24  | W:K30  | Acc:A24*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A25*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A24*K20  + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:A23*K30  + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:A25*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A24*K10  + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:A22*K30  + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:A24*K00  + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:A23*K10  + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:A22*K20  + 0        + 0        + 0       ] | [A:A54  | W:K33  | Acc:A44*K30  + A45*K31  + A53*K32  + A54*K33 ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A34', '0', '0', '0']
# [A:A34  | W:K00  | Acc:A34*K00  + 0        + 0        + 0       ] | [A:A33  | W:K10  | Acc:A33*K10  + 0        + 0        + 0       ] | [A:A32  | W:K20  | Acc:A32*K20  + 0        + 0        + 0       ] | [A:A25  | W:K30  | Acc:A25*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A25*K20  + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:A24*K30  + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A25*K10  + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:A24*K20  + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:A23*K30  + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:A25*K00  + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:A24*K10  + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:A23*K20  + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:A22*K30  + 0        + 0        + 0       ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A35', '0', '0', '0']
# [A:A35  | W:K00  | Acc:A35*K00  + 0        + 0        + 0       ] | [A:A34  | W:K10  | Acc:A34*K10  + 0        + 0        + 0       ] | [A:A33  | W:K20  | Acc:A33*K20  + 0        + 0        + 0       ] | [A:A32  | W:K30  | Acc:A32*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A34*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A33*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A32*K20  + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:A25*K30  + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:A25*K20  + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:A24*K30  + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:A32*K00  + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:A25*K10  + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:A24*K20  + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:A23*K30  + 0        + 0        + 0       ]
# Output:  ['Cxx_x', 'Cxx_x', 'Cxx_x', 'Cxx_x']
#
# New activations: ['A42', '0', '0', '0']
# [A:A42  | W:K00  | Acc:A42*K00  + 0        + 0        + 0       ] | [A:A35  | W:K10  | Acc:A35*K10  + 0        + 0        + 0       ] | [A:A34  | W:K20  | Acc:A34*K20  + 0        + 0        + 0       ] | [A:A33  | W:K30  | Acc:A33*K30  + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:A35*K00  + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:A34*K10  + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:A33*K20  + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:A32*K30  + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:A34*K00  + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:A33*K10  + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:A32*K20  + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:A25*K30  + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:A33*K00  + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:A32*K10  + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:A25*K20  + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:A24*K30  + 0        + 0        + 0       ]
# ...
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']
#
# New activations: ['0', '0', '0', '0']
# [A:0    | W:K00  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K10  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K20  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K30  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K01  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K11  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K21  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K31  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K02  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K12  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K22  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K32  | Acc:0        + 0        + 0        + 0       ]
# [A:0    | W:K03  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K13  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K23  | Acc:0        + 0        + 0        + 0       ] | [A:0    | W:K33  | Acc:0        + 0        + 0        + 0       ]
# Output:  ['000_0', '000_0', '000_0', '000_0']

# %%
pd.DataFrame(conv_sim.outputs)
# Out:
#         0      1      2      3
# 0   000_0  000_0  000_0  000_0
# 1   000_0  000_0  000_0  000_0
# 2   000_0  000_0  000_0  000_0
# 3   000_0  000_0  000_0  000_0
# 4   Cxx_x  000_0  000_0  000_0
# 5   Cxx_x  Cxx_x  000_0  000_0
# 6   Cxx_x  Cxx_x  Cxx_x  000_0
# 7   Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 8   Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 9   Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 10  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 11  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 12  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 13  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 14  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 15  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 16  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 17  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 18  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 19  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 20  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 21  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 22  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 23  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 24  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 25  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 26  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 27  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 28  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 29  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 30  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 31  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 32  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 33  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 34  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 35  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 36  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 37  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 38  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 39  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 40  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 41  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 42  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 43  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 44  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 45  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 46  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 47  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 48  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 49  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 50  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 51  Cxx_x  Cxx_x  Cxx_x  Cxx_x
# 52  000_0  Cxx_x  Cxx_x  Cxx_x
# 53  000_0  000_0  Cxx_x  Cxx_x
# 54  000_0  000_0  000_0  Cxx_x
# 55  000_0  000_0  000_0  000_0
# 56  000_0  000_0  000_0  000_0
# 57  000_0  000_0  000_0  000_0
# 58  000_0  000_0  000_0  000_0
# 59  000_0  000_0  000_0  000_0
# 60  000_0  000_0  000_0  000_0
# 61  000_0  000_0  000_0  000_0
# 62  000_0  000_0  000_0  000_0
# 63  000_0  000_0  000_0  000_0
# 64  000_0  000_0  000_0  000_0
# 65  000_0  000_0  000_0  000_0
# 66  000_0  000_0  000_0  000_0
# 67  000_0  000_0  000_0  000_0
# 68  000_0  000_0  000_0  000_0
# 69  000_0  000_0  000_0  000_0
# 70  000_0  000_0  000_0  000_0
# 71  000_0  000_0  000_0  000_0
# 72  000_0  000_0  000_0  000_0
# 73  000_0  000_0  000_0  000_0
# 74  000_0  000_0  000_0  000_0
# 75  000_0  000_0  000_0  000_0
# 76  000_0  000_0  000_0  000_0
# 77  000_0  000_0  000_0  000_0
# 78  000_0  000_0  000_0  000_0
# 79  000_0  000_0  000_0  000_0
# 80  000_0  000_0  000_0  000_0
# 81  000_0  000_0  000_0  000_0
# 82  000_0  000_0  000_0  000_0
# 83  000_0  000_0  000_0  000_0
# 84  000_0  000_0  000_0  000_0
# 85  000_0  000_0  000_0  000_0
# 86  000_0  000_0  000_0  000_0
# 87  000_0  000_0  000_0  000_0
# 88  000_0  000_0  000_0  000_0
# 89  000_0  000_0  000_0  000_0
# 90  000_0  000_0  000_0  000_0
# 91  000_0  000_0  000_0  000_0
# 92  000_0  000_0  000_0  000_0
# 93  000_0  000_0  000_0  000_0
# 94  000_0  000_0  000_0  000_0
# 95  000_0  000_0  000_0  000_0
# 96  000_0  000_0  000_0  000_0
# 97  000_0  000_0  000_0  000_0
# 98  000_0  000_0  000_0  000_0
# 99  000_0  000_0  000_0  000_0

# %%
for a in equations_matrix: 
    for b in a: 
        print(b)
# Out:
# ['A00*K00 + A01*K01 + A02*K02 + A03*K03 + A10*K10 + A11*K11 + A12*K12 + A13*K13 + A20*K20 + A21*K21 + A22*K22 + A23*K23 + A30*K30 + A31*K31 + A32*K32 + A33*K33',
#  'A01*K00 + A02*K01 + A03*K02 + A04*K03 + A11*K10 + A12*K11 + A13*K12 + A14*K13 + A21*K20 + A22*K21 + A23*K22 + A24*K23 + A31*K30 + A32*K31 + A33*K32 + A34*K33',
#  'A02*K00 + A03*K01 + A04*K02 + A05*K03 + A12*K10 + A13*K11 + A14*K12 + A15*K13 + A22*K20 + A23*K21 + A24*K22 + A25*K23 + A32*K30 + A33*K31 + A34*K32 + A35*K33',
#  'A10*K00 + A11*K01 + A12*K02 + A13*K03 + A20*K10 + A21*K11 + A22*K12 + A23*K13 + A30*K20 + A31*K21 + A32*K22 + A33*K23 + A40*K30 + A41*K31 + A42*K32 + A43*K33',
#  'A11*K00 + A12*K01 + A13*K02 + A14*K03 + A21*K10 + A22*K11 + A23*K12 + A24*K13 + A31*K20 + A32*K21 + A33*K22 + A34*K23 + A41*K30 + A42*K31 + A43*K32 + A44*K33',
#  'A12*K00 + A13*K01 + A14*K02 + A15*K03 + A22*K10 + A23*K11 + A24*K12 + A25*K13 + A32*K20 + A33*K21 + A34*K22 + A35*K23 + A42*K30 + A43*K31 + A44*K32 + A45*K33',
#  'A20*K00 + A21*K01 + A22*K02 + A23*K03 + A30*K10 + A31*K11 + A32*K12 + A33*K13 + A40*K20 + A41*K21 + A42*K22 + A43*K23 + A50*K30 + A51*K31 + A52*K32 + A53*K33',
#  'A21*K00 + A22*K01 + A23*K02 + A24*K03 + A31*K10 + A32*K11 + A33*K12 + A34*K13 + A41*K20 + A42*K21 + A43*K22 + A44*K23 + A51*K30 + A52*K31 + A53*K32 + A54*K33',
#  'A22*K00 + A23*K01 + A24*K02 + A25*K03 + A32*K10 + A33*K11 + A34*K12 + A35*K13 + A42*K20 + A43*K21 + A44*K22 + A45*K23 + A52*K30 + A53*K31 + A54*K32 + A55*K33']

# %%
patches
# Out:
# array([[['A00', 'A01', 'A02', 'A03'],
#         ['A10', 'A11', 'A12', 'A13'],
#         ['A20', 'A21', 'A22', 'A23'],
#         ['A30', 'A31', 'A32', 'A33']],
#
#        [['A01', 'A02', 'A03', 'A04'],
#         ['A11', 'A12', 'A13', 'A14'],
#         ['A21', 'A22', 'A23', 'A24'],
#         ['A31', 'A32', 'A33', 'A34']],
#
#        [['A02', 'A03', 'A04', 'A05'],
#         ['A12', 'A13', 'A14', 'A15'],
#         ['A22', 'A23', 'A24', 'A25'],
#         ['A32', 'A33', 'A34', 'A35']],
#
#        [['A10', 'A11', 'A12', 'A13'],
#         ['A20', 'A21', 'A22', 'A23'],
#         ['A30', 'A31', 'A32', 'A33'],
#         ['A40', 'A41', 'A42', 'A43']],
#
#        [['A11', 'A12', 'A13', 'A14'],
#         ['A21', 'A22', 'A23', 'A24'],
#         ['A31', 'A32', 'A33', 'A34'],
#         ['A41', 'A42', 'A43', 'A44']],
#
#        [['A12', 'A13', 'A14', 'A15'],
#         ['A22', 'A23', 'A24', 'A25'],
#         ['A32', 'A33', 'A34', 'A35'],
#         ['A42', 'A43', 'A44', 'A45']],
#
#        [['A20', 'A21', 'A22', 'A23'],
#         ['A30', 'A31', 'A32', 'A33'],
#         ['A40', 'A41', 'A42', 'A43'],
#         ['A50', 'A51', 'A52', 'A53']],
#
#        [['A21', 'A22', 'A23', 'A24'],
#         ['A31', 'A32', 'A33', 'A34'],
#         ['A41', 'A42', 'A43', 'A44'],
#         ['A51', 'A52', 'A53', 'A54']],
#
#        [['A22', 'A23', 'A24', 'A25'],
#         ['A32', 'A33', 'A34', 'A35'],
#         ['A42', 'A43', 'A44', 'A45'],
#         ['A52', 'A53', 'A54', 'A55']]], dtype='<U43')
