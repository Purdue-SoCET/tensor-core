# %%
import numpy as np
import pandas as pd
from typing import List, Optional

# %%
pd.set_option('display.max_rows', None)
# Out:
# test

# %%
# Input tensor shape: [N, H, W, C]
# Weight tensor shape: [R, S, C, K] 
# Output tensor shape: [N, P, Q, K]

def _output_size(I, K, P, S): 
    """Calculate output size with proper edge case handling"""
    if K > I + 2*P:
        return 0  # Kernel larger than padded input
    if S <= 0:
        raise ValueError("Stride must be positive")
    return int((I - K + 2*P) // S) + 1
    
def validate_conv_params(H, W, R, S, padding, stride):
    """Validate convolution parameters for edge cases"""
    if R > 32 or S > 32:
        raise ValueError("Kernel size cannot exceed 32x32")
    if R <= 0 or S <= 0:
        raise ValueError("Kernel size must be positive")
    if stride <= 0:
        raise ValueError("Stride must be positive")
    if padding < 0:
        raise ValueError("Padding cannot be negative")
    
    # Check if output size would be valid
    P = _output_size(H, R, padding, stride)
    Q = _output_size(W, S, padding, stride)
    if P <= 0 or Q <= 0:
        raise ValueError(f"Invalid configuration: kernel ({R}x{S}) too large for input ({H}x{W}) with padding {padding} and stride {stride}")
    
    return P, Q
    
N = 1 # batch size

H = 5 # activation height, activation width
W = 7
C = 1   # input channels <= strictly, grid_size (max PE size)
 
R = S = kernel_size = 4 # kernel height, kernel width
K = 1   # kernel channels, <= strictly, grid_size (max PE size)

# C and K don't need to be equal 

padding = 0
stride = 1

# Validate parameters and calculate output size
P, Q = validate_conv_params(H, W, R, S, padding, stride)
num_patches = P * Q 

input_shape = (N, H, W, C)
weight_shape = (R, S, C, K)
output_shape = (N, P, Q, K)

# %%
output_shape
# Out:
# (1, 2, 4, 1)

# %%
N_idx, H_idx, W_idx, C_idx = np.indices((N, H, W, C))
activations = np.char.add(
    np.char.add(
        np.char.add(
            np.char.add('A', N_idx.astype(str)),
            H_idx.astype(str)
        ),
        W_idx.astype(str)
    ),
    C_idx.astype(str)
)

# %%
I_ker, J_ker, C_ker, K_ker = np.indices((R, S, C, K))
kernel = np.char.add(
    np.char.add(
        np.char.add(
            np.char.add('K', I_ker.astype(str)),
            J_ker.astype(str)
        ),
        C_ker.astype(str)
    ),
    K_ker.astype(str)
)

# %%
kernel.flatten()
# Out:
# array(['K0000', 'K0100', 'K0200', 'K0300', 'K1000', 'K1100', 'K1200',
#        'K1300', 'K2000', 'K2100', 'K2200', 'K2300', 'K3000', 'K3100',
#        'K3200', 'K3300'], dtype='<U85')

# %%
equations_matrix = [[[[None for _ in range(K)] 
                      for _ in range(Q)] 
                     for _ in range(P)] 
                    for _ in range(N)]
patches = []
inv_patches = []

for n in range(N):
    # Calculate valid range for patch extraction with proper bounds checking
    max_i = max(0, H - R + 1) if H >= R else 0
    max_j = max(0, W - S + 1) if W >= S else 0
    
    for i in range(0, max_i, stride):
        for j in range(0, max_j, stride):
            # Validate patch bounds before extraction
            if i + R > H or j + S > W:
                continue  # Skip invalid patches
                
            # Extract a patch from image n
            patch = activations[n, i:i+R, j:j+S, :]   # shape (R, S, C)
            print(i)
            print(j)
            print(patch)
            
            # Validate patch shape
            if patch.shape != (R, S, C):
                print(f"Warning: Invalid patch shape {patch.shape}, expected ({R}, {S}, {C})")
                continue
                
            inv_patch = patch.transpose(1, 0, 2) # inverted: shape (S, R, C)
            patches.append(patch)
            inv_patches.append(inv_patch)
            
            for k_out in range(K):
                terms = []
                for a in range(R):
                    for b in range(S):
                        for c_idx in range(C):
                            # Each term: A{n}{i+a}{j+b}{c_idx} * K{a}{b}{c_idx}{k_out}
                            terms.append(f"{patch[a, b, c_idx]}*{kernel[a, b, c_idx, k_out]}")
                equation = " + ".join(terms)
                row_idx = i // stride
                col_idx = j // stride
                
                # Validate indices before assignment
                if (row_idx < len(equations_matrix[n]) and 
                    col_idx < len(equations_matrix[n][row_idx]) and
                    k_out < len(equations_matrix[n][row_idx][col_idx])):
                    equations_matrix[n][row_idx][col_idx][k_out] = equation
                else:
                    print(f"Warning: Invalid indices ({n}, {row_idx}, {col_idx}, {k_out})")
# Out:
# 0
# 0
# [[['A0000']
#   ['A0010']
#   ['A0020']
#   ['A0030']]
#
#  [['A0100']
#   ['A0110']
#   ['A0120']
#   ['A0130']]
#
#  [['A0200']
#   ['A0210']
#   ['A0220']
#   ['A0230']]
#
#  [['A0300']
#   ['A0310']
#   ['A0320']
#   ['A0330']]]
# 0
# 1
# [[['A0010']
#   ['A0020']
#   ['A0030']
#   ['A0040']]
#
#  [['A0110']
#   ['A0120']
#   ['A0130']
#   ['A0140']]
#
#  [['A0210']
#   ['A0220']
#   ['A0230']
#   ['A0240']]
#
#  [['A0310']
#   ['A0320']
#   ['A0330']
#   ['A0340']]]
# 0
# 2
# [[['A0020']
#   ['A0030']
#   ['A0040']
#   ['A0050']]
#
#  [['A0120']
#   ['A0130']
#   ['A0140']
#   ['A0150']]
#
#  [['A0220']
#   ['A0230']
#   ['A0240']
#   ['A0250']]
#
#  [['A0320']
#   ['A0330']
#   ['A0340']
#   ['A0350']]]
# 0
# 3
# [[['A0030']
#   ['A0040']
#   ['A0050']
#   ['A0060']]
#
#  [['A0130']
#   ['A0140']
#   ['A0150']
#   ['A0160']]
#
#  [['A0230']
#   ['A0240']
#   ['A0250']
#   ['A0260']]
#
#  [['A0330']
#   ['A0340']
#   ['A0350']
#   ['A0360']]]
# 1
# 0
# [[['A0100']
#   ['A0110']
#   ['A0120']
#   ['A0130']]
#
#  [['A0200']
#   ['A0210']
#   ['A0220']
#   ['A0230']]
#
#  [['A0300']
#   ['A0310']
#   ['A0320']
#   ['A0330']]
#
#  [['A0400']
#   ['A0410']
#   ['A0420']
#   ['A0430']]]
# 1
# 1
# [[['A0110']
#   ['A0120']
#   ['A0130']
#   ['A0140']]
#
#  [['A0210']
#   ['A0220']
#   ['A0230']
#   ['A0240']]
#
#  [['A0310']
#   ['A0320']
#   ['A0330']
#   ['A0340']]
#
#  [['A0410']
#   ['A0420']
#   ['A0430']
#   ['A0440']]]
# 1
# 2
# [[['A0120']
#   ['A0130']
#   ['A0140']
#   ['A0150']]
#
#  [['A0220']
#   ['A0230']
#   ['A0240']
#   ['A0250']]
#
#  [['A0320']
#   ['A0330']
#   ['A0340']
#   ['A0350']]
#
#  [['A0420']
#   ['A0430']
#   ['A0440']
#   ['A0450']]]
# 1
# 3
# [[['A0130']
#   ['A0140']
#   ['A0150']
#   ['A0160']]
#
#  [['A0230']
#   ['A0240']
#   ['A0250']
#   ['A0260']]
#
#  [['A0330']
#   ['A0340']
#   ['A0350']
#   ['A0360']]
#
#  [['A0430']
#   ['A0440']
#   ['A0450']
#   ['A0460']]]

# %%
split_equations_dict = {}

for n in range(N):
    for row_id in range(len(equations_matrix[n])):
        for col_id in range(len(equations_matrix[n][row_id])):
            for k_out in range(K):
                equation = equations_matrix[n][row_id][col_id][k_out]
                # each part corresponding to a kernel row
                terms = equation.split(" + ")
                split_eq = []
                num_terms_per_split = S * C  # originally, each kernel row contributed S * C terms.
                for r_idx in range(R):
                    start = r_idx * num_terms_per_split
                    end = (r_idx + 1) * num_terms_per_split
                    partial_eq = " + ".join(terms[start:end])
                    
                    subterms = partial_eq.split(" + ")
                    if len(subterms) > 4:
                        # even more break the partial equation into groups of 4 terms.
                        num_groups = (len(subterms) + 3) // 4  
                        for group in range(num_groups):
                            sub_start = group * 4
                            sub_end = (group + 1) * 4
                            sub_eq = " + ".join(subterms[sub_start:sub_end])
                            key = f"C{n}{row_id}{col_id}{k_out}_{r_idx}_{group}"
                            split_equations_dict[sub_eq] = key
                    else:
                        key = f"C{n}{row_id}{col_id}{k_out}_{r_idx}"
                        split_equations_dict[partial_eq] = key

# %%
equations_matrix
# Out:
# [[[['A0000*K0000 + A0010*K0100 + A0020*K0200 + A0030*K0300 + A0100*K1000 + A0110*K1100 + A0120*K1200 + A0130*K1300 + A0200*K2000 + A0210*K2100 + A0220*K2200 + A0230*K2300 + A0300*K3000 + A0310*K3100 + A0320*K3200 + A0330*K3300'],
#    ['A0010*K0000 + A0020*K0100 + A0030*K0200 + A0040*K0300 + A0110*K1000 + A0120*K1100 + A0130*K1200 + A0140*K1300 + A0210*K2000 + A0220*K2100 + A0230*K2200 + A0240*K2300 + A0310*K3000 + A0320*K3100 + A0330*K3200 + A0340*K3300'],
#    ['A0020*K0000 + A0030*K0100 + A0040*K0200 + A0050*K0300 + A0120*K1000 + A0130*K1100 + A0140*K1200 + A0150*K1300 + A0220*K2000 + A0230*K2100 + A0240*K2200 + A0250*K2300 + A0320*K3000 + A0330*K3100 + A0340*K3200 + A0350*K3300'],
#    ['A0030*K0000 + A0040*K0100 + A0050*K0200 + A0060*K0300 + A0130*K1000 + A0140*K1100 + A0150*K1200 + A0160*K1300 + A0230*K2000 + A0240*K2100 + A0250*K2200 + A0260*K2300 + A0330*K3000 + A0340*K3100 + A0350*K3200 + A0360*K3300']],
#   [['A0100*K0000 + A0110*K0100 + A0120*K0200 + A0130*K0300 + A0200*K1000 + A0210*K1100 + A0220*K1200 + A0230*K1300 + A0300*K2000 + A0310*K2100 + A0320*K2200 + A0330*K2300 + A0400*K3000 + A0410*K3100 + A0420*K3200 + A0430*K3300'],
#    ['A0110*K0000 + A0120*K0100 + A0130*K0200 + A0140*K0300 + A0210*K1000 + A0220*K1100 + A0230*K1200 + A0240*K1300 + A0310*K2000 + A0320*K2100 + A0330*K2200 + A0340*K2300 + A0410*K3000 + A0420*K3100 + A0430*K3200 + A0440*K3300'],
#    ['A0120*K0000 + A0130*K0100 + A0140*K0200 + A0150*K0300 + A0220*K1000 + A0230*K1100 + A0240*K1200 + A0250*K1300 + A0320*K2000 + A0330*K2100 + A0340*K2200 + A0350*K2300 + A0420*K3000 + A0430*K3100 + A0440*K3200 + A0450*K3300'],
#    ['A0130*K0000 + A0140*K0100 + A0150*K0200 + A0160*K0300 + A0230*K1000 + A0240*K1100 + A0250*K1200 + A0260*K1300 + A0330*K2000 + A0340*K2100 + A0350*K2200 + A0360*K2300 + A0430*K3000 + A0440*K3100 + A0450*K3200 + A0460*K3300']]]]

# %%
split_equations_dict
# Out:
# {'A0000*K0000 + A0010*K0100 + A0020*K0200 + A0030*K0300': 'C0000_0',
#  'A0100*K1000 + A0110*K1100 + A0120*K1200 + A0130*K1300': 'C0000_1',
#  'A0200*K2000 + A0210*K2100 + A0220*K2200 + A0230*K2300': 'C0000_2',
#  'A0300*K3000 + A0310*K3100 + A0320*K3200 + A0330*K3300': 'C0000_3',
#  'A0010*K0000 + A0020*K0100 + A0030*K0200 + A0040*K0300': 'C0010_0',
#  'A0110*K1000 + A0120*K1100 + A0130*K1200 + A0140*K1300': 'C0010_1',
#  'A0210*K2000 + A0220*K2100 + A0230*K2200 + A0240*K2300': 'C0010_2',
#  'A0310*K3000 + A0320*K3100 + A0330*K3200 + A0340*K3300': 'C0010_3',
#  'A0020*K0000 + A0030*K0100 + A0040*K0200 + A0050*K0300': 'C0020_0',
#  'A0120*K1000 + A0130*K1100 + A0140*K1200 + A0150*K1300': 'C0020_1',
#  'A0220*K2000 + A0230*K2100 + A0240*K2200 + A0250*K2300': 'C0020_2',
#  'A0320*K3000 + A0330*K3100 + A0340*K3200 + A0350*K3300': 'C0020_3',
#  'A0030*K0000 + A0040*K0100 + A0050*K0200 + A0060*K0300': 'C0030_0',
#  'A0130*K1000 + A0140*K1100 + A0150*K1200 + A0160*K1300': 'C0030_1',
#  'A0230*K2000 + A0240*K2100 + A0250*K2200 + A0260*K2300': 'C0030_2',
#  'A0330*K3000 + A0340*K3100 + A0350*K3200 + A0360*K3300': 'C0030_3',
#  'A0100*K0000 + A0110*K0100 + A0120*K0200 + A0130*K0300': 'C0100_0',
#  'A0200*K1000 + A0210*K1100 + A0220*K1200 + A0230*K1300': 'C0100_1',
#  'A0300*K2000 + A0310*K2100 + A0320*K2200 + A0330*K2300': 'C0100_2',
#  'A0400*K3000 + A0410*K3100 + A0420*K3200 + A0430*K3300': 'C0100_3',
#  'A0110*K0000 + A0120*K0100 + A0130*K0200 + A0140*K0300': 'C0110_0',
#  'A0210*K1000 + A0220*K1100 + A0230*K1200 + A0240*K1300': 'C0110_1',
#  'A0310*K2000 + A0320*K2100 + A0330*K2200 + A0340*K2300': 'C0110_2',
#  'A0410*K3000 + A0420*K3100 + A0430*K3200 + A0440*K3300': 'C0110_3',
#  'A0120*K0000 + A0130*K0100 + A0140*K0200 + A0150*K0300': 'C0120_0',
#  'A0220*K1000 + A0230*K1100 + A0240*K1200 + A0250*K1300': 'C0120_1',
#  'A0320*K2000 + A0330*K2100 + A0340*K2200 + A0350*K2300': 'C0120_2',
#  'A0420*K3000 + A0430*K3100 + A0440*K3200 + A0450*K3300': 'C0120_3',
#  'A0130*K0000 + A0140*K0100 + A0150*K0200 + A0160*K0300': 'C0130_0',
#  'A0230*K1000 + A0240*K1100 + A0250*K1200 + A0260*K1300': 'C0130_1',
#  'A0330*K2000 + A0340*K2100 + A0350*K2200 + A0360*K2300': 'C0130_2',
#  'A0430*K3000 + A0440*K3100 + A0450*K3200 + A0460*K3300': 'C0130_3'}

# %%
patches = np.array(patches)
inv_patches = np.array(inv_patches)

# %%
patches.shape
# Out:
# (8, 4, 4, 1)

# %%
kernel.flatten()
# Out:
# array(['K0000', 'K0100', 'K0200', 'K0300', 'K1000', 'K1100', 'K1200',
#        'K1300', 'K2000', 'K2100', 'K2200', 'K2300', 'K3000', 'K3100',
#        'K3200', 'K3300'], dtype='<U85')

# %%
class PE:
    # links: [0: left, 1: up, 2: right, 3: down]
    def __init__(self, links: Optional[List['PE']] = None):
        if links is None:
            links = [None, None, None, None]
        self.links = links
        self.activation = "0"
        self.weight = '--'
        self.accumulation: str = "0"
    
    def _input(self, activation: str):
        self.activation = activation
    
    def _weight(self, weight: str):
        self.weight = weight
    
    def shift(self, shift_direction: int, activation_flag: bool):
        neighbor = self.links[shift_direction]
        if neighbor is not None:
            if activation_flag:
                neighbor._input(self.activation)
            else:
                neighbor._weight(self.weight)

class SystolicArray:
    def __init__(self, size: int):
        self.size = size
        self.buffer = []  
        self.array = self._setup_array()
    
    def _setup_array(self):
        array = [[PE() for _ in range(self.size)] for _ in range(self.size)]
        for i in range(self.size):
            for j in range(self.size):
                left = array[i][j-1] if j > 0 else None
                up = array[i-1][j] if i > 0 else None
                right = array[i][j+1] if j < self.size - 1 else None
                down = array[i+1][j] if i < self.size - 1 else None
                array[i][j].links = [left, up, right, down]
        return array

    def print_array(self):
        for i in range(self.size):
            row_parts = []
            for pe in self.array[i]:
                act_str = pe.activation.ljust(12)
                weight_str = pe.weight.ljust(12)
                
                if pe.accumulation.strip() == "0":
                    parts = self.size * ["0"]
                else:
                    parts = [p.strip() for p in pe.accumulation.split('+')]
                    while len(parts) < kernel_size:
                        parts.append("0")
                    parts = parts[:4]
                parts = [p.ljust(12) for p in parts]
                acc_str = " + ".join(parts)
                
                row_parts.append(f"[A:{act_str} | W:{weight_str} | Acc:{acc_str}]")
            print(" | ".join(row_parts))

    def cycle(self, new_activations: Optional[List[str]] = None):
        if new_activations:
            for i in range(self.size):
                #  shift activations rightward
                for j in range(self.size - 1, 0, -1):
                    self.array[i][j].activation = self.array[i][j-1].activation
                # shift the new activation into column 0.
                self.array[i][0].activation = new_activations[i]
        
        bottom_row = [self.array[self.size - 1][j].accumulation for j in range(self.size)]
        self.buffer.append(bottom_row)
        # Look to get the equations
        
        for j in range(self.size):
            # save previous cycle's accumulations for column j
            prev_acc = [self.array[i][j].accumulation for i in range(self.size)]
            
            # Update the accumulation in row 0 for column j.
            cell0 = self.array[0][j]
            prod0 = f"{cell0.activation}*{cell0.weight}" if cell0.activation not in ["0", "--"] else "0"
            cell0.accumulation = prod0
            
            for i in range(1, self.size):
                cell = self.array[i][j]
                prod = f"{cell.activation}*{cell.weight}" if cell.activation not in ["0", "--"] else "0"
                inherited = prev_acc[i-1]
                if inherited == "0":
                    new_acc = prod
                else:
                    new_acc = inherited + (f" + {prod}" if prod != "0" else "")
                cell.accumulation = new_acc if new_acc != "" else "0"

# %%
class Conv2dSimulator:
    def __init__(self, grid_size: int):
        self.input_buffers = [
            [],              
            ["0"],           
            ["0", "0"],      
            ["0", "0", "0"] 
        ]
        
        self.grid_size = grid_size
        self.systolic_array = SystolicArray(grid_size)
        self.outputs = [] 
        self.weight_update_flag = False
        self.kernel_update_iter = 0
        self.total_cycles = 1
        
        self.cycles_per_weight_frame = P * Q + 6
        self.current_cycle_count = 0
        
        self.current_kernel = None 
        self.current_kernel_index = 0  
        self.flat_patch = None
        self.complete = 0 

    def add_patches(self, patches: List[np.ndarray]):     
        flat_patch = []
        if (C + K) > 2: 
            for h in range(patches.shape[1]):       # patches.shape[1] = H
                for w in range(patches.shape[2]):     # patches.shape[2] = W
                    for n in range(patches.shape[0]):  # patches.shape[0] = N
                        for c in range(patches.shape[3]): # patches.shape[3] = C
                            flat_patch.append(patches[n, h, w, c])
        else: 
            for n in range(patches.shape[0]):  # patches.shape[0] = N
                for h in range(patches.shape[1]):       # patches.shape[1] = H
                    for w in range(patches.shape[2]):     # patches.shape[2] = W
                        for c in range(patches.shape[3]): # patches.shape[3] = C
                            flat_patch.append(patches[n, h, w, c])
        self.flat_patch = flat_patch

        counter = 0
        for i in range(0, len(flat_patch), self.grid_size):
            chunk = flat_patch[i:i + self.grid_size]
            if len(chunk) < self.grid_size:
                chunk.extend(["0"] * (self.grid_size - len(chunk)))
            for j in range(self.grid_size):
                self.input_buffers[j].append(chunk[j])

            if (counter == (P * Q - 1)): 
                counter = 0
                for j in range(self.grid_size):
                    self.input_buffers[j].extend(["0"]*6)
            else: counter += 1

    def add_kernel(self, kernel: np.ndarray):
        self.current_kernel = kernel  
        self.current_kernel_index = 0  # start at the beginning of this kernel frame
        self.switch_weights()

    def switch_weights(self):
        grid_size = self.grid_size
        total_needed = grid_size * grid_size

        to_return = 0
        if (C + K) > 2: 
            flat_weights = self.current_kernel.flatten().tolist()
        else: 
            flat_weights = self.current_kernel.T.flatten().tolist()

        total_weights = len(flat_weights)

        start = self.current_kernel_index
        end = start + total_needed

        # If there aren't enough weights left, take what remains and pad with zeros.
        if end > total_weights:
            selected = flat_weights[start:] + [0] * (end - total_weights)
            self.complete = 1
            self.current_kernel_index = 0
        else:
            selected = flat_weights[start:end]
            self.current_kernel_index += total_needed
            if self.current_kernel_index >= total_weights:
                self.complete = 1
                self.current_kernel_index = 0

        for i in range(grid_size):
            for j in range(grid_size):
                idx = i * grid_size + j
                self.systolic_array.array[i][j].weight = selected[idx]

        self.kernel_update_iter += 1
        self.weight_update_flag = True
        self.current_cycle_count = 0
        print(f"Switched weights. Kernel update iteration: {self.kernel_update_iter}")
        return to_return

    def cycle(self):
        new_activations = []
        status = 0
        for i in range(self.systolic_array.size):
            if self.input_buffers[i]:
                new_act = self.input_buffers[i].pop(0)
            else:
                new_act = "0"
            new_activations.append(new_act)

        print("Total Cycles: ", self.total_cycles)
        
        print("New activations:", new_activations)
        self.systolic_array.cycle(new_activations=new_activations)
        self.systolic_array.print_array()

        output = self.systolic_array.buffer[-1]
        translated_equations = [] 
        for _out in output: 
            try: 
                translated_equations.append(split_equations_dict[_out])
            except:
                # Cxx_x fix
                cycle_num = self.total_cycles
                col_num = len(translated_equations)
                if _out == "0":
                    translated_equations.append(f"Czero_{cycle_num}_{col_num}")
                elif "*" in _out and "+" in _out:
                    translated_equations.append(f"Cpartial_{cycle_num}_{col_num}")
                elif "*" in _out:
                    translated_equations.append(f"Csingle_{cycle_num}_{col_num}")
                else:
                    translated_equations.append(f"Cunknown_{cycle_num}_{col_num}")
        self.outputs.append(translated_equations)
        print("Output: ", translated_equations)

        self.current_cycle_count += 1
        if not self.complete and (self.current_cycle_count >= self.cycles_per_weight_frame):
            print(f"Completed {self.current_cycle_count} cycles for current weight frame. Switching weights.")
            status = self.switch_weights()

        if self.complete: 
            print("Convolution Completed!")

        self.total_cycles += 1

        return translated_equations, status

# %%
kernel.shape
# Out:
# (4, 4, 1, 1)

# %%
conv_sim = Conv2dSimulator(kernel_size)
conv_sim.add_patches(patches)
conv_sim.add_kernel(kernel)
print(conv_sim.input_buffers[0])

for cycle_num in range(200):
    out, status = conv_sim.cycle()
    print()

    # Keep the same flow of activations, we need to check if we can move the weights in (flat similar to the log file), in a upper-left triangle way
# Out:
# Switched weights. Kernel update iteration: 1
# [np.str_('A0000'), np.str_('A0100'), np.str_('A0200'), np.str_('A0300'), np.str_('A0010'), np.str_('A0110'), np.str_('A0210'), np.str_('A0310'), '0', '0', '0', '0', '0', '0', np.str_('A0020'), np.str_('A0120'), np.str_('A0220'), np.str_('A0320'), np.str_('A0030'), np.str_('A0130'), np.str_('A0230'), np.str_('A0330'), '0', '0', '0', '0', '0', '0', np.str_('A0100'), np.str_('A0200'), np.str_('A0300'), np.str_('A0400'), np.str_('A0110'), np.str_('A0210'), np.str_('A0310'), np.str_('A0410'), '0', '0', '0', '0', '0', '0', np.str_('A0120'), np.str_('A0220'), np.str_('A0320'), np.str_('A0420'), np.str_('A0130'), np.str_('A0230'), np.str_('A0330'), np.str_('A0430'), '0', '0', '0', '0', '0', '0']
# Total Cycles:  1
# New activations: [np.str_('A0000'), '0', '0', '0']
# [A:A0000        | W:K0000        | Acc:A0000*K0000  + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_1_0', 'Czero_1_1', 'Czero_1_2', 'Czero_1_3']
# Convolution Completed!
#
# Total Cycles:  2
# New activations: [np.str_('A0100'), np.str_('A0010'), '0', '0']
# [A:A0100        | W:K0000        | Acc:A0100*K0000  + 0            + 0            + 0           ] | [A:A0000        | W:K1000        | Acc:A0000*K1000  + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:A0010        | W:K0100        | Acc:A0000*K0000  + A0010*K0100  + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_2_0', 'Czero_2_1', 'Czero_2_2', 'Czero_2_3']
# Convolution Completed!
#
# Total Cycles:  3
# New activations: [np.str_('A0200'), np.str_('A0110'), np.str_('A0020'), '0']
# [A:A0200        | W:K0000        | Acc:A0200*K0000  + 0            + 0            + 0           ] | [A:A0100        | W:K1000        | Acc:A0100*K1000  + 0            + 0            + 0           ] | [A:A0000        | W:K2000        | Acc:A0000*K2000  + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:A0110        | W:K0100        | Acc:A0100*K0000  + A0110*K0100  + 0            + 0           ] | [A:A0010        | W:K1100        | Acc:A0000*K1000  + A0010*K1100  + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:A0020        | W:K0200        | Acc:A0000*K0000  + A0010*K0100  + A0020*K0200  + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_3_0', 'Czero_3_1', 'Czero_3_2', 'Czero_3_3']
# Convolution Completed!
#
# Total Cycles:  4
# New activations: [np.str_('A0300'), np.str_('A0210'), np.str_('A0120'), np.str_('A0030')]
# [A:A0300        | W:K0000        | Acc:A0300*K0000  + 0            + 0            + 0           ] | [A:A0200        | W:K1000        | Acc:A0200*K1000  + 0            + 0            + 0           ] | [A:A0100        | W:K2000        | Acc:A0100*K2000  + 0            + 0            + 0           ] | [A:A0000        | W:K3000        | Acc:A0000*K3000  + 0            + 0            + 0           ]
# [A:A0210        | W:K0100        | Acc:A0200*K0000  + A0210*K0100  + 0            + 0           ] | [A:A0110        | W:K1100        | Acc:A0100*K1000  + A0110*K1100  + 0            + 0           ] | [A:A0010        | W:K2100        | Acc:A0000*K2000  + A0010*K2100  + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:A0120        | W:K0200        | Acc:A0100*K0000  + A0110*K0100  + A0120*K0200  + 0           ] | [A:A0020        | W:K1200        | Acc:A0000*K1000  + A0010*K1100  + A0020*K1200  + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:A0030        | W:K0300        | Acc:A0000*K0000  + A0010*K0100  + A0020*K0200  + A0030*K0300 ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_4_0', 'Czero_4_1', 'Czero_4_2', 'Czero_4_3']
# Convolution Completed!
#
# Total Cycles:  5
# New activations: [np.str_('A0010'), np.str_('A0310'), np.str_('A0220'), np.str_('A0130')]
# [A:A0010        | W:K0000        | Acc:A0010*K0000  + 0            + 0            + 0           ] | [A:A0300        | W:K1000        | Acc:A0300*K1000  + 0            + 0            + 0           ] | [A:A0200        | W:K2000        | Acc:A0200*K2000  + 0            + 0            + 0           ] | [A:A0100        | W:K3000        | Acc:A0100*K3000  + 0            + 0            + 0           ]
# [A:A0310        | W:K0100        | Acc:A0300*K0000  + A0310*K0100  + 0            + 0           ] | [A:A0210        | W:K1100        | Acc:A0200*K1000  + A0210*K1100  + 0            + 0           ] | [A:A0110        | W:K2100        | Acc:A0100*K2000  + A0110*K2100  + 0            + 0           ] | [A:A0010        | W:K3100        | Acc:A0000*K3000  + A0010*K3100  + 0            + 0           ]
# [A:A0220        | W:K0200        | Acc:A0200*K0000  + A0210*K0100  + A0220*K0200  + 0           ] | [A:A0120        | W:K1200        | Acc:A0100*K1000  + A0110*K1100  + A0120*K1200  + 0           ] | [A:A0020        | W:K2200        | Acc:A0000*K2000  + A0010*K2100  + A0020*K2200  + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:A0130        | W:K0300        | Acc:A0100*K0000  + A0110*K0100  + A0120*K0200  + A0130*K0300 ] | [A:A0030        | W:K1300        | Acc:A0000*K1000  + A0010*K1100  + A0020*K1200  + A0030*K1300 ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['C0000_0', 'Czero_5_1', 'Czero_5_2', 'Czero_5_3']
# Convolution Completed!
#
# Total Cycles:  6
# New activations: [np.str_('A0110'), np.str_('A0020'), np.str_('A0320'), np.str_('A0230')]
# [A:A0110        | W:K0000        | Acc:A0110*K0000  + 0            + 0            + 0           ] | [A:A0010        | W:K1000        | Acc:A0010*K1000  + 0            + 0            + 0           ] | [A:A0300        | W:K2000        | Acc:A0300*K2000  + 0            + 0            + 0           ] | [A:A0200        | W:K3000        | Acc:A0200*K3000  + 0            + 0            + 0           ]
# [A:A0020        | W:K0100        | Acc:A0010*K0000  + A0020*K0100  + 0            + 0           ] | [A:A0310        | W:K1100        | Acc:A0300*K1000  + A0310*K1100  + 0            + 0           ] | [A:A0210        | W:K2100        | Acc:A0200*K2000  + A0210*K2100  + 0            + 0           ] | [A:A0110        | W:K3100        | Acc:A0100*K3000  + A0110*K3100  + 0            + 0           ]
# [A:A0320        | W:K0200        | Acc:A0300*K0000  + A0310*K0100  + A0320*K0200  + 0           ] | [A:A0220        | W:K1200        | Acc:A0200*K1000  + A0210*K1100  + A0220*K1200  + 0           ] | [A:A0120        | W:K2200        | Acc:A0100*K2000  + A0110*K2100  + A0120*K2200  + 0           ] | [A:A0020        | W:K3200        | Acc:A0000*K3000  + A0010*K3100  + A0020*K3200  + 0           ]
# [A:A0230        | W:K0300        | Acc:A0200*K0000  + A0210*K0100  + A0220*K0200  + A0230*K0300 ] | [A:A0130        | W:K1300        | Acc:A0100*K1000  + A0110*K1100  + A0120*K1200  + A0130*K1300 ] | [A:A0030        | W:K2300        | Acc:A0000*K2000  + A0010*K2100  + A0020*K2200  + A0030*K2300 ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['C0100_0', 'Cpartial_6_1', 'Czero_6_2', 'Czero_6_3']
# Convolution Completed!
#
# Total Cycles:  7
# New activations: [np.str_('A0210'), np.str_('A0120'), np.str_('A0030'), np.str_('A0330')]
# [A:A0210        | W:K0000        | Acc:A0210*K0000  + 0            + 0            + 0           ] | [A:A0110        | W:K1000        | Acc:A0110*K1000  + 0            + 0            + 0           ] | [A:A0010        | W:K2000        | Acc:A0010*K2000  + 0            + 0            + 0           ] | [A:A0300        | W:K3000        | Acc:A0300*K3000  + 0            + 0            + 0           ]
# [A:A0120        | W:K0100        | Acc:A0110*K0000  + A0120*K0100  + 0            + 0           ] | [A:A0020        | W:K1100        | Acc:A0010*K1000  + A0020*K1100  + 0            + 0           ] | [A:A0310        | W:K2100        | Acc:A0300*K2000  + A0310*K2100  + 0            + 0           ] | [A:A0210        | W:K3100        | Acc:A0200*K3000  + A0210*K3100  + 0            + 0           ]
# [A:A0030        | W:K0200        | Acc:A0010*K0000  + A0020*K0100  + A0030*K0200  + 0           ] | [A:A0320        | W:K1200        | Acc:A0300*K1000  + A0310*K1100  + A0320*K1200  + 0           ] | [A:A0220        | W:K2200        | Acc:A0200*K2000  + A0210*K2100  + A0220*K2200  + 0           ] | [A:A0120        | W:K3200        | Acc:A0100*K3000  + A0110*K3100  + A0120*K3200  + 0           ]
# [A:A0330        | W:K0300        | Acc:A0300*K0000  + A0310*K0100  + A0320*K0200  + A0330*K0300 ] | [A:A0230        | W:K1300        | Acc:A0200*K1000  + A0210*K1100  + A0220*K1200  + A0230*K1300 ] | [A:A0130        | W:K2300        | Acc:A0100*K2000  + A0110*K2100  + A0120*K2200  + A0130*K2300 ] | [A:A0030        | W:K3300        | Acc:A0000*K3000  + A0010*K3100  + A0020*K3200  + A0030*K3300 ]
# Output:  ['Cpartial_7_0', 'C0000_1', 'Cpartial_7_2', 'Czero_7_3']
# Convolution Completed!
#
# Total Cycles:  8
# New activations: [np.str_('A0310'), np.str_('A0220'), np.str_('A0130'), np.str_('A0040')]
# [A:A0310        | W:K0000        | Acc:A0310*K0000  + 0            + 0            + 0           ] | [A:A0210        | W:K1000        | Acc:A0210*K1000  + 0            + 0            + 0           ] | [A:A0110        | W:K2000        | Acc:A0110*K2000  + 0            + 0            + 0           ] | [A:A0010        | W:K3000        | Acc:A0010*K3000  + 0            + 0            + 0           ]
# [A:A0220        | W:K0100        | Acc:A0210*K0000  + A0220*K0100  + 0            + 0           ] | [A:A0120        | W:K1100        | Acc:A0110*K1000  + A0120*K1100  + 0            + 0           ] | [A:A0020        | W:K2100        | Acc:A0010*K2000  + A0020*K2100  + 0            + 0           ] | [A:A0310        | W:K3100        | Acc:A0300*K3000  + A0310*K3100  + 0            + 0           ]
# [A:A0130        | W:K0200        | Acc:A0110*K0000  + A0120*K0100  + A0130*K0200  + 0           ] | [A:A0030        | W:K1200        | Acc:A0010*K1000  + A0020*K1100  + A0030*K1200  + 0           ] | [A:A0320        | W:K2200        | Acc:A0300*K2000  + A0310*K2100  + A0320*K2200  + 0           ] | [A:A0220        | W:K3200        | Acc:A0200*K3000  + A0210*K3100  + A0220*K3200  + 0           ]
# [A:A0040        | W:K0300        | Acc:A0010*K0000  + A0020*K0100  + A0030*K0200  + A0040*K0300 ] | [A:A0330        | W:K1300        | Acc:A0300*K1000  + A0310*K1100  + A0320*K1200  + A0330*K1300 ] | [A:A0230        | W:K2300        | Acc:A0200*K2000  + A0210*K2100  + A0220*K2200  + A0230*K2300 ] | [A:A0130        | W:K3300        | Acc:A0100*K3000  + A0110*K3100  + A0120*K3200  + A0130*K3300 ]
# Output:  ['Cpartial_8_0', 'C0100_1', 'Cpartial_8_2', 'Cpartial_8_3']
# Convolution Completed!
#
# Total Cycles:  9
# New activations: ['0', np.str_('A0320'), np.str_('A0230'), np.str_('A0140')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:A0310        | W:K1000        | Acc:A0310*K1000  + 0            + 0            + 0           ] | [A:A0210        | W:K2000        | Acc:A0210*K2000  + 0            + 0            + 0           ] | [A:A0110        | W:K3000        | Acc:A0110*K3000  + 0            + 0            + 0           ]
# [A:A0320        | W:K0100        | Acc:A0310*K0000  + A0320*K0100  + 0            + 0           ] | [A:A0220        | W:K1100        | Acc:A0210*K1000  + A0220*K1100  + 0            + 0           ] | [A:A0120        | W:K2100        | Acc:A0110*K2000  + A0120*K2100  + 0            + 0           ] | [A:A0020        | W:K3100        | Acc:A0010*K3000  + A0020*K3100  + 0            + 0           ]
# [A:A0230        | W:K0200        | Acc:A0210*K0000  + A0220*K0100  + A0230*K0200  + 0           ] | [A:A0130        | W:K1200        | Acc:A0110*K1000  + A0120*K1100  + A0130*K1200  + 0           ] | [A:A0030        | W:K2200        | Acc:A0010*K2000  + A0020*K2100  + A0030*K2200  + 0           ] | [A:A0320        | W:K3200        | Acc:A0300*K3000  + A0310*K3100  + A0320*K3200  + 0           ]
# [A:A0140        | W:K0300        | Acc:A0110*K0000  + A0120*K0100  + A0130*K0200  + A0140*K0300 ] | [A:A0040        | W:K1300        | Acc:A0010*K1000  + A0020*K1100  + A0030*K1200  + A0040*K1300 ] | [A:A0330        | W:K2300        | Acc:A0300*K2000  + A0310*K2100  + A0320*K2200  + A0330*K2300 ] | [A:A0230        | W:K3300        | Acc:A0200*K3000  + A0210*K3100  + A0220*K3200  + A0230*K3300 ]
# Output:  ['C0010_0', 'Cpartial_9_1', 'C0000_2', 'Cpartial_9_3']
# Convolution Completed!
#
# Total Cycles:  10
# New activations: ['0', '0', np.str_('A0330'), np.str_('A0240')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:A0310        | W:K2000        | Acc:A0310*K2000  + 0            + 0            + 0           ] | [A:A0210        | W:K3000        | Acc:A0210*K3000  + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:A0320        | W:K1100        | Acc:A0310*K1000  + A0320*K1100  + 0            + 0           ] | [A:A0220        | W:K2100        | Acc:A0210*K2000  + A0220*K2100  + 0            + 0           ] | [A:A0120        | W:K3100        | Acc:A0110*K3000  + A0120*K3100  + 0            + 0           ]
# [A:A0330        | W:K0200        | Acc:A0310*K0000  + A0320*K0100  + A0330*K0200  + 0           ] | [A:A0230        | W:K1200        | Acc:A0210*K1000  + A0220*K1100  + A0230*K1200  + 0           ] | [A:A0130        | W:K2200        | Acc:A0110*K2000  + A0120*K2100  + A0130*K2200  + 0           ] | [A:A0030        | W:K3200        | Acc:A0010*K3000  + A0020*K3100  + A0030*K3200  + 0           ]
# [A:A0240        | W:K0300        | Acc:A0210*K0000  + A0220*K0100  + A0230*K0200  + A0240*K0300 ] | [A:A0140        | W:K1300        | Acc:A0110*K1000  + A0120*K1100  + A0130*K1200  + A0140*K1300 ] | [A:A0040        | W:K2300        | Acc:A0010*K2000  + A0020*K2100  + A0030*K2200  + A0040*K2300 ] | [A:A0330        | W:K3300        | Acc:A0300*K3000  + A0310*K3100  + A0320*K3200  + A0330*K3300 ]
# Output:  ['C0110_0', 'Cpartial_10_1', 'C0100_2', 'Cpartial_10_3']
# Convolution Completed!
#
# Total Cycles:  11
# New activations: ['0', '0', '0', np.str_('A0340')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:A0310        | W:K3000        | Acc:A0310*K3000  + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:A0320        | W:K2100        | Acc:A0310*K2000  + A0320*K2100  + 0            + 0           ] | [A:A0220        | W:K3100        | Acc:A0210*K3000  + A0220*K3100  + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K1200        | Acc:A0310*K1000  + A0320*K1100  + A0330*K1200  + 0           ] | [A:A0230        | W:K2200        | Acc:A0210*K2000  + A0220*K2100  + A0230*K2200  + 0           ] | [A:A0130        | W:K3200        | Acc:A0110*K3000  + A0120*K3100  + A0130*K3200  + 0           ]
# [A:A0340        | W:K0300        | Acc:A0310*K0000  + A0320*K0100  + A0330*K0200  + A0340*K0300 ] | [A:A0240        | W:K1300        | Acc:A0210*K1000  + A0220*K1100  + A0230*K1200  + A0240*K1300 ] | [A:A0140        | W:K2300        | Acc:A0110*K2000  + A0120*K2100  + A0130*K2200  + A0140*K2300 ] | [A:A0040        | W:K3300        | Acc:A0010*K3000  + A0020*K3100  + A0030*K3200  + A0040*K3300 ]
# Output:  ['Cpartial_11_0', 'C0010_1', 'Cpartial_11_2', 'C0000_3']
# Convolution Completed!
#
# Total Cycles:  12
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:A0320        | W:K3100        | Acc:A0310*K3000  + A0320*K3100  + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K2200        | Acc:A0310*K2000  + A0320*K2100  + A0330*K2200  + 0           ] | [A:A0230        | W:K3200        | Acc:A0210*K3000  + A0220*K3100  + A0230*K3200  + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K1300        | Acc:A0310*K1000  + A0320*K1100  + A0330*K1200  + A0340*K1300 ] | [A:A0240        | W:K2300        | Acc:A0210*K2000  + A0220*K2100  + A0230*K2200  + A0240*K2300 ] | [A:A0140        | W:K3300        | Acc:A0110*K3000  + A0120*K3100  + A0130*K3200  + A0140*K3300 ]
# Output:  ['Cpartial_12_0', 'C0110_1', 'Cpartial_12_2', 'Cpartial_12_3']
# Convolution Completed!
#
# Total Cycles:  13
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K3200        | Acc:A0310*K3000  + A0320*K3100  + A0330*K3200  + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K2300        | Acc:A0310*K2000  + A0320*K2100  + A0330*K2200  + A0340*K2300 ] | [A:A0240        | W:K3300        | Acc:A0210*K3000  + A0220*K3100  + A0230*K3200  + A0240*K3300 ]
# Output:  ['Czero_13_0', 'Cpartial_13_1', 'C0010_2', 'Cpartial_13_3']
# Convolution Completed!
#
# Total Cycles:  14
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K3300        | Acc:A0310*K3000  + A0320*K3100  + A0330*K3200  + A0340*K3300 ]
# Output:  ['Czero_14_0', 'Czero_14_1', 'C0110_2', 'Cpartial_14_3']
# Convolution Completed!
#
# Total Cycles:  15
# New activations: [np.str_('A0020'), '0', '0', '0']
# [A:A0020        | W:K0000        | Acc:A0020*K0000  + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_15_0', 'Czero_15_1', 'Czero_15_2', 'C0010_3']
# Convolution Completed!
#
# Total Cycles:  16
# New activations: [np.str_('A0120'), np.str_('A0030'), '0', '0']
# [A:A0120        | W:K0000        | Acc:A0120*K0000  + 0            + 0            + 0           ] | [A:A0020        | W:K1000        | Acc:A0020*K1000  + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:A0030        | W:K0100        | Acc:A0020*K0000  + A0030*K0100  + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_16_0', 'Czero_16_1', 'Czero_16_2', 'Czero_16_3']
# Convolution Completed!
#
# Total Cycles:  17
# New activations: [np.str_('A0220'), np.str_('A0130'), np.str_('A0040'), '0']
# [A:A0220        | W:K0000        | Acc:A0220*K0000  + 0            + 0            + 0           ] | [A:A0120        | W:K1000        | Acc:A0120*K1000  + 0            + 0            + 0           ] | [A:A0020        | W:K2000        | Acc:A0020*K2000  + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:A0130        | W:K0100        | Acc:A0120*K0000  + A0130*K0100  + 0            + 0           ] | [A:A0030        | W:K1100        | Acc:A0020*K1000  + A0030*K1100  + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:A0040        | W:K0200        | Acc:A0020*K0000  + A0030*K0100  + A0040*K0200  + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_17_0', 'Czero_17_1', 'Czero_17_2', 'Czero_17_3']
# Convolution Completed!
#
# Total Cycles:  18
# New activations: [np.str_('A0320'), np.str_('A0230'), np.str_('A0140'), np.str_('A0050')]
# [A:A0320        | W:K0000        | Acc:A0320*K0000  + 0            + 0            + 0           ] | [A:A0220        | W:K1000        | Acc:A0220*K1000  + 0            + 0            + 0           ] | [A:A0120        | W:K2000        | Acc:A0120*K2000  + 0            + 0            + 0           ] | [A:A0020        | W:K3000        | Acc:A0020*K3000  + 0            + 0            + 0           ]
# [A:A0230        | W:K0100        | Acc:A0220*K0000  + A0230*K0100  + 0            + 0           ] | [A:A0130        | W:K1100        | Acc:A0120*K1000  + A0130*K1100  + 0            + 0           ] | [A:A0030        | W:K2100        | Acc:A0020*K2000  + A0030*K2100  + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:A0140        | W:K0200        | Acc:A0120*K0000  + A0130*K0100  + A0140*K0200  + 0           ] | [A:A0040        | W:K1200        | Acc:A0020*K1000  + A0030*K1100  + A0040*K1200  + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:A0050        | W:K0300        | Acc:A0020*K0000  + A0030*K0100  + A0040*K0200  + A0050*K0300 ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_18_0', 'Czero_18_1', 'Czero_18_2', 'Czero_18_3']
# Convolution Completed!
#
# Total Cycles:  19
# New activations: [np.str_('A0030'), np.str_('A0330'), np.str_('A0240'), np.str_('A0150')]
# [A:A0030        | W:K0000        | Acc:A0030*K0000  + 0            + 0            + 0           ] | [A:A0320        | W:K1000        | Acc:A0320*K1000  + 0            + 0            + 0           ] | [A:A0220        | W:K2000        | Acc:A0220*K2000  + 0            + 0            + 0           ] | [A:A0120        | W:K3000        | Acc:A0120*K3000  + 0            + 0            + 0           ]
# [A:A0330        | W:K0100        | Acc:A0320*K0000  + A0330*K0100  + 0            + 0           ] | [A:A0230        | W:K1100        | Acc:A0220*K1000  + A0230*K1100  + 0            + 0           ] | [A:A0130        | W:K2100        | Acc:A0120*K2000  + A0130*K2100  + 0            + 0           ] | [A:A0030        | W:K3100        | Acc:A0020*K3000  + A0030*K3100  + 0            + 0           ]
# [A:A0240        | W:K0200        | Acc:A0220*K0000  + A0230*K0100  + A0240*K0200  + 0           ] | [A:A0140        | W:K1200        | Acc:A0120*K1000  + A0130*K1100  + A0140*K1200  + 0           ] | [A:A0040        | W:K2200        | Acc:A0020*K2000  + A0030*K2100  + A0040*K2200  + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:A0150        | W:K0300        | Acc:A0120*K0000  + A0130*K0100  + A0140*K0200  + A0150*K0300 ] | [A:A0050        | W:K1300        | Acc:A0020*K1000  + A0030*K1100  + A0040*K1200  + A0050*K1300 ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['C0020_0', 'Czero_19_1', 'Czero_19_2', 'Czero_19_3']
# Convolution Completed!
#
# Total Cycles:  20
# New activations: [np.str_('A0130'), np.str_('A0040'), np.str_('A0340'), np.str_('A0250')]
# [A:A0130        | W:K0000        | Acc:A0130*K0000  + 0            + 0            + 0           ] | [A:A0030        | W:K1000        | Acc:A0030*K1000  + 0            + 0            + 0           ] | [A:A0320        | W:K2000        | Acc:A0320*K2000  + 0            + 0            + 0           ] | [A:A0220        | W:K3000        | Acc:A0220*K3000  + 0            + 0            + 0           ]
# [A:A0040        | W:K0100        | Acc:A0030*K0000  + A0040*K0100  + 0            + 0           ] | [A:A0330        | W:K1100        | Acc:A0320*K1000  + A0330*K1100  + 0            + 0           ] | [A:A0230        | W:K2100        | Acc:A0220*K2000  + A0230*K2100  + 0            + 0           ] | [A:A0130        | W:K3100        | Acc:A0120*K3000  + A0130*K3100  + 0            + 0           ]
# [A:A0340        | W:K0200        | Acc:A0320*K0000  + A0330*K0100  + A0340*K0200  + 0           ] | [A:A0240        | W:K1200        | Acc:A0220*K1000  + A0230*K1100  + A0240*K1200  + 0           ] | [A:A0140        | W:K2200        | Acc:A0120*K2000  + A0130*K2100  + A0140*K2200  + 0           ] | [A:A0040        | W:K3200        | Acc:A0020*K3000  + A0030*K3100  + A0040*K3200  + 0           ]
# [A:A0250        | W:K0300        | Acc:A0220*K0000  + A0230*K0100  + A0240*K0200  + A0250*K0300 ] | [A:A0150        | W:K1300        | Acc:A0120*K1000  + A0130*K1100  + A0140*K1200  + A0150*K1300 ] | [A:A0050        | W:K2300        | Acc:A0020*K2000  + A0030*K2100  + A0040*K2200  + A0050*K2300 ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['C0120_0', 'Cpartial_20_1', 'Czero_20_2', 'Czero_20_3']
# Convolution Completed!
#
# Total Cycles:  21
# New activations: [np.str_('A0230'), np.str_('A0140'), np.str_('A0050'), np.str_('A0350')]
# [A:A0230        | W:K0000        | Acc:A0230*K0000  + 0            + 0            + 0           ] | [A:A0130        | W:K1000        | Acc:A0130*K1000  + 0            + 0            + 0           ] | [A:A0030        | W:K2000        | Acc:A0030*K2000  + 0            + 0            + 0           ] | [A:A0320        | W:K3000        | Acc:A0320*K3000  + 0            + 0            + 0           ]
# [A:A0140        | W:K0100        | Acc:A0130*K0000  + A0140*K0100  + 0            + 0           ] | [A:A0040        | W:K1100        | Acc:A0030*K1000  + A0040*K1100  + 0            + 0           ] | [A:A0330        | W:K2100        | Acc:A0320*K2000  + A0330*K2100  + 0            + 0           ] | [A:A0230        | W:K3100        | Acc:A0220*K3000  + A0230*K3100  + 0            + 0           ]
# [A:A0050        | W:K0200        | Acc:A0030*K0000  + A0040*K0100  + A0050*K0200  + 0           ] | [A:A0340        | W:K1200        | Acc:A0320*K1000  + A0330*K1100  + A0340*K1200  + 0           ] | [A:A0240        | W:K2200        | Acc:A0220*K2000  + A0230*K2100  + A0240*K2200  + 0           ] | [A:A0140        | W:K3200        | Acc:A0120*K3000  + A0130*K3100  + A0140*K3200  + 0           ]
# [A:A0350        | W:K0300        | Acc:A0320*K0000  + A0330*K0100  + A0340*K0200  + A0350*K0300 ] | [A:A0250        | W:K1300        | Acc:A0220*K1000  + A0230*K1100  + A0240*K1200  + A0250*K1300 ] | [A:A0150        | W:K2300        | Acc:A0120*K2000  + A0130*K2100  + A0140*K2200  + A0150*K2300 ] | [A:A0050        | W:K3300        | Acc:A0020*K3000  + A0030*K3100  + A0040*K3200  + A0050*K3300 ]
# Output:  ['Cpartial_21_0', 'C0020_1', 'Cpartial_21_2', 'Czero_21_3']
# Convolution Completed!
#
# Total Cycles:  22
# New activations: [np.str_('A0330'), np.str_('A0240'), np.str_('A0150'), np.str_('A0060')]
# [A:A0330        | W:K0000        | Acc:A0330*K0000  + 0            + 0            + 0           ] | [A:A0230        | W:K1000        | Acc:A0230*K1000  + 0            + 0            + 0           ] | [A:A0130        | W:K2000        | Acc:A0130*K2000  + 0            + 0            + 0           ] | [A:A0030        | W:K3000        | Acc:A0030*K3000  + 0            + 0            + 0           ]
# [A:A0240        | W:K0100        | Acc:A0230*K0000  + A0240*K0100  + 0            + 0           ] | [A:A0140        | W:K1100        | Acc:A0130*K1000  + A0140*K1100  + 0            + 0           ] | [A:A0040        | W:K2100        | Acc:A0030*K2000  + A0040*K2100  + 0            + 0           ] | [A:A0330        | W:K3100        | Acc:A0320*K3000  + A0330*K3100  + 0            + 0           ]
# [A:A0150        | W:K0200        | Acc:A0130*K0000  + A0140*K0100  + A0150*K0200  + 0           ] | [A:A0050        | W:K1200        | Acc:A0030*K1000  + A0040*K1100  + A0050*K1200  + 0           ] | [A:A0340        | W:K2200        | Acc:A0320*K2000  + A0330*K2100  + A0340*K2200  + 0           ] | [A:A0240        | W:K3200        | Acc:A0220*K3000  + A0230*K3100  + A0240*K3200  + 0           ]
# [A:A0060        | W:K0300        | Acc:A0030*K0000  + A0040*K0100  + A0050*K0200  + A0060*K0300 ] | [A:A0350        | W:K1300        | Acc:A0320*K1000  + A0330*K1100  + A0340*K1200  + A0350*K1300 ] | [A:A0250        | W:K2300        | Acc:A0220*K2000  + A0230*K2100  + A0240*K2200  + A0250*K2300 ] | [A:A0150        | W:K3300        | Acc:A0120*K3000  + A0130*K3100  + A0140*K3200  + A0150*K3300 ]
# Output:  ['Cpartial_22_0', 'C0120_1', 'Cpartial_22_2', 'Cpartial_22_3']
# Convolution Completed!
#
# Total Cycles:  23
# New activations: ['0', np.str_('A0340'), np.str_('A0250'), np.str_('A0160')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K1000        | Acc:A0330*K1000  + 0            + 0            + 0           ] | [A:A0230        | W:K2000        | Acc:A0230*K2000  + 0            + 0            + 0           ] | [A:A0130        | W:K3000        | Acc:A0130*K3000  + 0            + 0            + 0           ]
# [A:A0340        | W:K0100        | Acc:A0330*K0000  + A0340*K0100  + 0            + 0           ] | [A:A0240        | W:K1100        | Acc:A0230*K1000  + A0240*K1100  + 0            + 0           ] | [A:A0140        | W:K2100        | Acc:A0130*K2000  + A0140*K2100  + 0            + 0           ] | [A:A0040        | W:K3100        | Acc:A0030*K3000  + A0040*K3100  + 0            + 0           ]
# [A:A0250        | W:K0200        | Acc:A0230*K0000  + A0240*K0100  + A0250*K0200  + 0           ] | [A:A0150        | W:K1200        | Acc:A0130*K1000  + A0140*K1100  + A0150*K1200  + 0           ] | [A:A0050        | W:K2200        | Acc:A0030*K2000  + A0040*K2100  + A0050*K2200  + 0           ] | [A:A0340        | W:K3200        | Acc:A0320*K3000  + A0330*K3100  + A0340*K3200  + 0           ]
# [A:A0160        | W:K0300        | Acc:A0130*K0000  + A0140*K0100  + A0150*K0200  + A0160*K0300 ] | [A:A0060        | W:K1300        | Acc:A0030*K1000  + A0040*K1100  + A0050*K1200  + A0060*K1300 ] | [A:A0350        | W:K2300        | Acc:A0320*K2000  + A0330*K2100  + A0340*K2200  + A0350*K2300 ] | [A:A0250        | W:K3300        | Acc:A0220*K3000  + A0230*K3100  + A0240*K3200  + A0250*K3300 ]
# Output:  ['C0030_0', 'Cpartial_23_1', 'C0020_2', 'Cpartial_23_3']
# Convolution Completed!
#
# Total Cycles:  24
# New activations: ['0', '0', np.str_('A0350'), np.str_('A0260')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K2000        | Acc:A0330*K2000  + 0            + 0            + 0           ] | [A:A0230        | W:K3000        | Acc:A0230*K3000  + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K1100        | Acc:A0330*K1000  + A0340*K1100  + 0            + 0           ] | [A:A0240        | W:K2100        | Acc:A0230*K2000  + A0240*K2100  + 0            + 0           ] | [A:A0140        | W:K3100        | Acc:A0130*K3000  + A0140*K3100  + 0            + 0           ]
# [A:A0350        | W:K0200        | Acc:A0330*K0000  + A0340*K0100  + A0350*K0200  + 0           ] | [A:A0250        | W:K1200        | Acc:A0230*K1000  + A0240*K1100  + A0250*K1200  + 0           ] | [A:A0150        | W:K2200        | Acc:A0130*K2000  + A0140*K2100  + A0150*K2200  + 0           ] | [A:A0050        | W:K3200        | Acc:A0030*K3000  + A0040*K3100  + A0050*K3200  + 0           ]
# [A:A0260        | W:K0300        | Acc:A0230*K0000  + A0240*K0100  + A0250*K0200  + A0260*K0300 ] | [A:A0160        | W:K1300        | Acc:A0130*K1000  + A0140*K1100  + A0150*K1200  + A0160*K1300 ] | [A:A0060        | W:K2300        | Acc:A0030*K2000  + A0040*K2100  + A0050*K2200  + A0060*K2300 ] | [A:A0350        | W:K3300        | Acc:A0320*K3000  + A0330*K3100  + A0340*K3200  + A0350*K3300 ]
# Output:  ['C0130_0', 'Cpartial_24_1', 'C0120_2', 'Cpartial_24_3']
# Convolution Completed!
#
# Total Cycles:  25
# New activations: ['0', '0', '0', np.str_('A0360')]
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:A0330        | W:K3000        | Acc:A0330*K3000  + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K2100        | Acc:A0330*K2000  + A0340*K2100  + 0            + 0           ] | [A:A0240        | W:K3100        | Acc:A0230*K3000  + A0240*K3100  + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:A0350        | W:K1200        | Acc:A0330*K1000  + A0340*K1100  + A0350*K1200  + 0           ] | [A:A0250        | W:K2200        | Acc:A0230*K2000  + A0240*K2100  + A0250*K2200  + 0           ] | [A:A0150        | W:K3200        | Acc:A0130*K3000  + A0140*K3100  + A0150*K3200  + 0           ]
# [A:A0360        | W:K0300        | Acc:A0330*K0000  + A0340*K0100  + A0350*K0200  + A0360*K0300 ] | [A:A0260        | W:K1300        | Acc:A0230*K1000  + A0240*K1100  + A0250*K1200  + A0260*K1300 ] | [A:A0160        | W:K2300        | Acc:A0130*K2000  + A0140*K2100  + A0150*K2200  + A0160*K2300 ] | [A:A0060        | W:K3300        | Acc:A0030*K3000  + A0040*K3100  + A0050*K3200  + A0060*K3300 ]
# Output:  ['Cpartial_25_0', 'C0030_1', 'Cpartial_25_2', 'C0020_3']
# Convolution Completed!
#
# Total Cycles:  26
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:A0340        | W:K3100        | Acc:A0330*K3000  + A0340*K3100  + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:A0350        | W:K2200        | Acc:A0330*K2000  + A0340*K2100  + A0350*K2200  + 0           ] | [A:A0250        | W:K3200        | Acc:A0230*K3000  + A0240*K3100  + A0250*K3200  + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:A0360        | W:K1300        | Acc:A0330*K1000  + A0340*K1100  + A0350*K1200  + A0360*K1300 ] | [A:A0260        | W:K2300        | Acc:A0230*K2000  + A0240*K2100  + A0250*K2200  + A0260*K2300 ] | [A:A0160        | W:K3300        | Acc:A0130*K3000  + A0140*K3100  + A0150*K3200  + A0160*K3300 ]
# Output:  ['Cpartial_26_0', 'C0130_1', 'Cpartial_26_2', 'Cpartial_26_3']
# Convolution Completed!
#
# Total Cycles:  27
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:A0350        | W:K3200        | Acc:A0330*K3000  + A0340*K3100  + A0350*K3200  + 0           ]
# ...
# Output:  ['Czero_191_0', 'Czero_191_1', 'Czero_191_2', 'Czero_191_3']
# Convolution Completed!
#
# Total Cycles:  192
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_192_0', 'Czero_192_1', 'Czero_192_2', 'Czero_192_3']
# Convolution Completed!
#
# Total Cycles:  193
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_193_0', 'Czero_193_1', 'Czero_193_2', 'Czero_193_3']
# Convolution Completed!
#
# Total Cycles:  194
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_194_0', 'Czero_194_1', 'Czero_194_2', 'Czero_194_3']
# Convolution Completed!
#
# Total Cycles:  195
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_195_0', 'Czero_195_1', 'Czero_195_2', 'Czero_195_3']
# Convolution Completed!
#
# Total Cycles:  196
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_196_0', 'Czero_196_1', 'Czero_196_2', 'Czero_196_3']
# Convolution Completed!
#
# Total Cycles:  197
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_197_0', 'Czero_197_1', 'Czero_197_2', 'Czero_197_3']
# Convolution Completed!
#
# Total Cycles:  198
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_198_0', 'Czero_198_1', 'Czero_198_2', 'Czero_198_3']
# Convolution Completed!
#
# Total Cycles:  199
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_199_0', 'Czero_199_1', 'Czero_199_2', 'Czero_199_3']
# Convolution Completed!
#
# Total Cycles:  200
# New activations: ['0', '0', '0', '0']
# [A:0            | W:K0000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2000        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3000        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2100        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3100        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2200        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3200        | Acc:0            + 0            + 0            + 0           ]
# [A:0            | W:K0300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K1300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K2300        | Acc:0            + 0            + 0            + 0           ] | [A:0            | W:K3300        | Acc:0            + 0            + 0            + 0           ]
# Output:  ['Czero_200_0', 'Czero_200_1', 'Czero_200_2', 'Czero_200_3']
# Convolution Completed!

# %%
patches[4]
# Out:
# array([[['A0100'],
#         ['A0110'],
#         ['A0120'],
#         ['A0130']],
#
#        [['A0200'],
#         ['A0210'],
#         ['A0220'],
#         ['A0230']],
#
#        [['A0300'],
#         ['A0310'],
#         ['A0320'],
#         ['A0330']],
#
#        [['A0400'],
#         ['A0410'],
#         ['A0420'],
#         ['A0430']]], dtype='<U85')

# %%
pd.DataFrame(conv_sim.outputs)
# Out:
#                  0              1              2              3
# 0        Czero_1_0      Czero_1_1      Czero_1_2      Czero_1_3
# 1        Czero_2_0      Czero_2_1      Czero_2_2      Czero_2_3
# 2        Czero_3_0      Czero_3_1      Czero_3_2      Czero_3_3
# 3        Czero_4_0      Czero_4_1      Czero_4_2      Czero_4_3
# 4          C0000_0      Czero_5_1      Czero_5_2      Czero_5_3
# 5          C0100_0   Cpartial_6_1      Czero_6_2      Czero_6_3
# 6     Cpartial_7_0        C0000_1   Cpartial_7_2      Czero_7_3
# 7     Cpartial_8_0        C0100_1   Cpartial_8_2   Cpartial_8_3
# 8          C0010_0   Cpartial_9_1        C0000_2   Cpartial_9_3
# 9          C0110_0  Cpartial_10_1        C0100_2  Cpartial_10_3
# 10   Cpartial_11_0        C0010_1  Cpartial_11_2        C0000_3
# 11   Cpartial_12_0        C0110_1  Cpartial_12_2  Cpartial_12_3
# 12      Czero_13_0  Cpartial_13_1        C0010_2  Cpartial_13_3
# 13      Czero_14_0     Czero_14_1        C0110_2  Cpartial_14_3
# 14      Czero_15_0     Czero_15_1     Czero_15_2        C0010_3
# 15      Czero_16_0     Czero_16_1     Czero_16_2     Czero_16_3
# 16      Czero_17_0     Czero_17_1     Czero_17_2     Czero_17_3
# 17      Czero_18_0     Czero_18_1     Czero_18_2     Czero_18_3
# 18         C0020_0     Czero_19_1     Czero_19_2     Czero_19_3
# 19         C0120_0  Cpartial_20_1     Czero_20_2     Czero_20_3
# 20   Cpartial_21_0        C0020_1  Cpartial_21_2     Czero_21_3
# 21   Cpartial_22_0        C0120_1  Cpartial_22_2  Cpartial_22_3
# 22         C0030_0  Cpartial_23_1        C0020_2  Cpartial_23_3
# 23         C0130_0  Cpartial_24_1        C0120_2  Cpartial_24_3
# 24   Cpartial_25_0        C0030_1  Cpartial_25_2        C0020_3
# 25   Cpartial_26_0        C0130_1  Cpartial_26_2  Cpartial_26_3
# 26      Czero_27_0  Cpartial_27_1        C0030_2  Cpartial_27_3
# 27      Czero_28_0     Czero_28_1        C0130_2  Cpartial_28_3
# 28      Czero_29_0     Czero_29_1     Czero_29_2        C0030_3
# 29      Czero_30_0     Czero_30_1     Czero_30_2     Czero_30_3
# 30      Czero_31_0     Czero_31_1     Czero_31_2     Czero_31_3
# 31      Czero_32_0     Czero_32_1     Czero_32_2     Czero_32_3
# 32         C0100_0     Czero_33_1     Czero_33_2     Czero_33_3
# 33   Cpartial_34_0        C0000_1     Czero_34_2     Czero_34_3
# 34   Cpartial_35_0        C0100_1  Cpartial_35_2     Czero_35_3
# 35   Cpartial_36_0  Cpartial_36_1        C0000_2  Cpartial_36_3
# 36         C0110_0  Cpartial_37_1        C0100_2  Cpartial_37_3
# 37   Cpartial_38_0        C0010_1  Cpartial_38_2        C0000_3
# 38   Cpartial_39_0        C0110_1  Cpartial_39_2        C0100_3
# 39   Cpartial_40_0  Cpartial_40_1        C0010_2  Cpartial_40_3
# 40      Czero_41_0  Cpartial_41_1        C0110_2  Cpartial_41_3
# 41      Czero_42_0     Czero_42_1  Cpartial_42_2        C0010_3
# 42      Czero_43_0     Czero_43_1     Czero_43_2        C0110_3
# 43      Czero_44_0     Czero_44_1     Czero_44_2     Czero_44_3
# 44      Czero_45_0     Czero_45_1     Czero_45_2     Czero_45_3
# 45      Czero_46_0     Czero_46_1     Czero_46_2     Czero_46_3
# 46         C0120_0     Czero_47_1     Czero_47_2     Czero_47_3
# 47   Cpartial_48_0        C0020_1     Czero_48_2     Czero_48_3
# 48   Cpartial_49_0        C0120_1  Cpartial_49_2     Czero_49_3
# 49   Cpartial_50_0  Cpartial_50_1        C0020_2  Cpartial_50_3
# 50         C0130_0  Cpartial_51_1        C0120_2  Cpartial_51_3
# 51   Cpartial_52_0        C0030_1  Cpartial_52_2        C0020_3
# 52   Cpartial_53_0        C0130_1  Cpartial_53_2        C0120_3
# 53   Cpartial_54_0  Cpartial_54_1        C0030_2  Cpartial_54_3
# 54      Czero_55_0  Cpartial_55_1        C0130_2  Cpartial_55_3
# 55      Czero_56_0     Czero_56_1  Cpartial_56_2        C0030_3
# 56      Czero_57_0     Czero_57_1     Czero_57_2        C0130_3
# 57      Czero_58_0     Czero_58_1     Czero_58_2     Czero_58_3
# 58      Czero_59_0     Czero_59_1     Czero_59_2     Czero_59_3
# 59      Czero_60_0     Czero_60_1     Czero_60_2     Czero_60_3
# 60      Czero_61_0     Czero_61_1     Czero_61_2     Czero_61_3
# 61      Czero_62_0     Czero_62_1     Czero_62_2     Czero_62_3
# 62      Czero_63_0     Czero_63_1     Czero_63_2     Czero_63_3
# 63      Czero_64_0     Czero_64_1     Czero_64_2     Czero_64_3
# 64      Czero_65_0     Czero_65_1     Czero_65_2     Czero_65_3
# 65      Czero_66_0     Czero_66_1     Czero_66_2     Czero_66_3
# 66      Czero_67_0     Czero_67_1     Czero_67_2     Czero_67_3
# 67      Czero_68_0     Czero_68_1     Czero_68_2     Czero_68_3
# 68      Czero_69_0     Czero_69_1     Czero_69_2     Czero_69_3
# 69      Czero_70_0     Czero_70_1     Czero_70_2     Czero_70_3
# 70      Czero_71_0     Czero_71_1     Czero_71_2     Czero_71_3
# 71      Czero_72_0     Czero_72_1     Czero_72_2     Czero_72_3
# 72      Czero_73_0     Czero_73_1     Czero_73_2     Czero_73_3
# 73      Czero_74_0     Czero_74_1     Czero_74_2     Czero_74_3
# 74      Czero_75_0     Czero_75_1     Czero_75_2     Czero_75_3
# 75      Czero_76_0     Czero_76_1     Czero_76_2     Czero_76_3
# 76      Czero_77_0     Czero_77_1     Czero_77_2     Czero_77_3
# 77      Czero_78_0     Czero_78_1     Czero_78_2     Czero_78_3
# 78      Czero_79_0     Czero_79_1     Czero_79_2     Czero_79_3
# 79      Czero_80_0     Czero_80_1     Czero_80_2     Czero_80_3
# 80      Czero_81_0     Czero_81_1     Czero_81_2     Czero_81_3
# 81      Czero_82_0     Czero_82_1     Czero_82_2     Czero_82_3
# 82      Czero_83_0     Czero_83_1     Czero_83_2     Czero_83_3
# 83      Czero_84_0     Czero_84_1     Czero_84_2     Czero_84_3
# 84      Czero_85_0     Czero_85_1     Czero_85_2     Czero_85_3
# 85      Czero_86_0     Czero_86_1     Czero_86_2     Czero_86_3
# 86      Czero_87_0     Czero_87_1     Czero_87_2     Czero_87_3
# 87      Czero_88_0     Czero_88_1     Czero_88_2     Czero_88_3
# 88      Czero_89_0     Czero_89_1     Czero_89_2     Czero_89_3
# 89      Czero_90_0     Czero_90_1     Czero_90_2     Czero_90_3
# 90      Czero_91_0     Czero_91_1     Czero_91_2     Czero_91_3
# 91      Czero_92_0     Czero_92_1     Czero_92_2     Czero_92_3
# 92      Czero_93_0     Czero_93_1     Czero_93_2     Czero_93_3
# 93      Czero_94_0     Czero_94_1     Czero_94_2     Czero_94_3
# 94      Czero_95_0     Czero_95_1     Czero_95_2     Czero_95_3
# 95      Czero_96_0     Czero_96_1     Czero_96_2     Czero_96_3
# 96      Czero_97_0     Czero_97_1     Czero_97_2     Czero_97_3
# 97      Czero_98_0     Czero_98_1     Czero_98_2     Czero_98_3
# 98      Czero_99_0     Czero_99_1     Czero_99_2     Czero_99_3
# 99     Czero_100_0    Czero_100_1    Czero_100_2    Czero_100_3
# 100    Czero_101_0    Czero_101_1    Czero_101_2    Czero_101_3
# 101    Czero_102_0    Czero_102_1    Czero_102_2    Czero_102_3
# 102    Czero_103_0    Czero_103_1    Czero_103_2    Czero_103_3
# 103    Czero_104_0    Czero_104_1    Czero_104_2    Czero_104_3
# 104    Czero_105_0    Czero_105_1    Czero_105_2    Czero_105_3
# 105    Czero_106_0    Czero_106_1    Czero_106_2    Czero_106_3
# 106    Czero_107_0    Czero_107_1    Czero_107_2    Czero_107_3
# 107    Czero_108_0    Czero_108_1    Czero_108_2    Czero_108_3
# 108    Czero_109_0    Czero_109_1    Czero_109_2    Czero_109_3
# 109    Czero_110_0    Czero_110_1    Czero_110_2    Czero_110_3
# 110    Czero_111_0    Czero_111_1    Czero_111_2    Czero_111_3
# 111    Czero_112_0    Czero_112_1    Czero_112_2    Czero_112_3
# 112    Czero_113_0    Czero_113_1    Czero_113_2    Czero_113_3
# 113    Czero_114_0    Czero_114_1    Czero_114_2    Czero_114_3
# 114    Czero_115_0    Czero_115_1    Czero_115_2    Czero_115_3
# 115    Czero_116_0    Czero_116_1    Czero_116_2    Czero_116_3
# 116    Czero_117_0    Czero_117_1    Czero_117_2    Czero_117_3
# 117    Czero_118_0    Czero_118_1    Czero_118_2    Czero_118_3
# 118    Czero_119_0    Czero_119_1    Czero_119_2    Czero_119_3
# 119    Czero_120_0    Czero_120_1    Czero_120_2    Czero_120_3
# 120    Czero_121_0    Czero_121_1    Czero_121_2    Czero_121_3
# 121    Czero_122_0    Czero_122_1    Czero_122_2    Czero_122_3
# 122    Czero_123_0    Czero_123_1    Czero_123_2    Czero_123_3
# 123    Czero_124_0    Czero_124_1    Czero_124_2    Czero_124_3
# 124    Czero_125_0    Czero_125_1    Czero_125_2    Czero_125_3
# 125    Czero_126_0    Czero_126_1    Czero_126_2    Czero_126_3
# 126    Czero_127_0    Czero_127_1    Czero_127_2    Czero_127_3
# 127    Czero_128_0    Czero_128_1    Czero_128_2    Czero_128_3
# 128    Czero_129_0    Czero_129_1    Czero_129_2    Czero_129_3
# 129    Czero_130_0    Czero_130_1    Czero_130_2    Czero_130_3
# 130    Czero_131_0    Czero_131_1    Czero_131_2    Czero_131_3
# 131    Czero_132_0    Czero_132_1    Czero_132_2    Czero_132_3
# 132    Czero_133_0    Czero_133_1    Czero_133_2    Czero_133_3
# 133    Czero_134_0    Czero_134_1    Czero_134_2    Czero_134_3
# 134    Czero_135_0    Czero_135_1    Czero_135_2    Czero_135_3
# 135    Czero_136_0    Czero_136_1    Czero_136_2    Czero_136_3
# 136    Czero_137_0    Czero_137_1    Czero_137_2    Czero_137_3
# 137    Czero_138_0    Czero_138_1    Czero_138_2    Czero_138_3
# 138    Czero_139_0    Czero_139_1    Czero_139_2    Czero_139_3
# 139    Czero_140_0    Czero_140_1    Czero_140_2    Czero_140_3
# 140    Czero_141_0    Czero_141_1    Czero_141_2    Czero_141_3
# 141    Czero_142_0    Czero_142_1    Czero_142_2    Czero_142_3
# 142    Czero_143_0    Czero_143_1    Czero_143_2    Czero_143_3
# 143    Czero_144_0    Czero_144_1    Czero_144_2    Czero_144_3
# 144    Czero_145_0    Czero_145_1    Czero_145_2    Czero_145_3
# 145    Czero_146_0    Czero_146_1    Czero_146_2    Czero_146_3
# 146    Czero_147_0    Czero_147_1    Czero_147_2    Czero_147_3
# 147    Czero_148_0    Czero_148_1    Czero_148_2    Czero_148_3
# 148    Czero_149_0    Czero_149_1    Czero_149_2    Czero_149_3
# 149    Czero_150_0    Czero_150_1    Czero_150_2    Czero_150_3
# 150    Czero_151_0    Czero_151_1    Czero_151_2    Czero_151_3
# 151    Czero_152_0    Czero_152_1    Czero_152_2    Czero_152_3
# 152    Czero_153_0    Czero_153_1    Czero_153_2    Czero_153_3
# 153    Czero_154_0    Czero_154_1    Czero_154_2    Czero_154_3
# 154    Czero_155_0    Czero_155_1    Czero_155_2    Czero_155_3
# 155    Czero_156_0    Czero_156_1    Czero_156_2    Czero_156_3
# 156    Czero_157_0    Czero_157_1    Czero_157_2    Czero_157_3
# 157    Czero_158_0    Czero_158_1    Czero_158_2    Czero_158_3
# 158    Czero_159_0    Czero_159_1    Czero_159_2    Czero_159_3
# 159    Czero_160_0    Czero_160_1    Czero_160_2    Czero_160_3
# 160    Czero_161_0    Czero_161_1    Czero_161_2    Czero_161_3
# 161    Czero_162_0    Czero_162_1    Czero_162_2    Czero_162_3
# 162    Czero_163_0    Czero_163_1    Czero_163_2    Czero_163_3
# 163    Czero_164_0    Czero_164_1    Czero_164_2    Czero_164_3
# 164    Czero_165_0    Czero_165_1    Czero_165_2    Czero_165_3
# 165    Czero_166_0    Czero_166_1    Czero_166_2    Czero_166_3
# 166    Czero_167_0    Czero_167_1    Czero_167_2    Czero_167_3
# 167    Czero_168_0    Czero_168_1    Czero_168_2    Czero_168_3
# 168    Czero_169_0    Czero_169_1    Czero_169_2    Czero_169_3
# 169    Czero_170_0    Czero_170_1    Czero_170_2    Czero_170_3
# 170    Czero_171_0    Czero_171_1    Czero_171_2    Czero_171_3
# 171    Czero_172_0    Czero_172_1    Czero_172_2    Czero_172_3
# 172    Czero_173_0    Czero_173_1    Czero_173_2    Czero_173_3
# 173    Czero_174_0    Czero_174_1    Czero_174_2    Czero_174_3
# 174    Czero_175_0    Czero_175_1    Czero_175_2    Czero_175_3
# 175    Czero_176_0    Czero_176_1    Czero_176_2    Czero_176_3
# 176    Czero_177_0    Czero_177_1    Czero_177_2    Czero_177_3
# 177    Czero_178_0    Czero_178_1    Czero_178_2    Czero_178_3
# 178    Czero_179_0    Czero_179_1    Czero_179_2    Czero_179_3
# 179    Czero_180_0    Czero_180_1    Czero_180_2    Czero_180_3
# 180    Czero_181_0    Czero_181_1    Czero_181_2    Czero_181_3
# 181    Czero_182_0    Czero_182_1    Czero_182_2    Czero_182_3
# 182    Czero_183_0    Czero_183_1    Czero_183_2    Czero_183_3
# 183    Czero_184_0    Czero_184_1    Czero_184_2    Czero_184_3
# 184    Czero_185_0    Czero_185_1    Czero_185_2    Czero_185_3
# 185    Czero_186_0    Czero_186_1    Czero_186_2    Czero_186_3
# 186    Czero_187_0    Czero_187_1    Czero_187_2    Czero_187_3
# 187    Czero_188_0    Czero_188_1    Czero_188_2    Czero_188_3
# 188    Czero_189_0    Czero_189_1    Czero_189_2    Czero_189_3
# 189    Czero_190_0    Czero_190_1    Czero_190_2    Czero_190_3
# 190    Czero_191_0    Czero_191_1    Czero_191_2    Czero_191_3
# 191    Czero_192_0    Czero_192_1    Czero_192_2    Czero_192_3
# 192    Czero_193_0    Czero_193_1    Czero_193_2    Czero_193_3
# 193    Czero_194_0    Czero_194_1    Czero_194_2    Czero_194_3
# 194    Czero_195_0    Czero_195_1    Czero_195_2    Czero_195_3
# 195    Czero_196_0    Czero_196_1    Czero_196_2    Czero_196_3
# 196    Czero_197_0    Czero_197_1    Czero_197_2    Czero_197_3
# 197    Czero_198_0    Czero_198_1    Czero_198_2    Czero_198_3
# 198    Czero_199_0    Czero_199_1    Czero_199_2    Czero_199_3
# 199    Czero_200_0    Czero_200_1    Czero_200_2    Czero_200_3

# %%
# Edge case testing function
def test_edge_cases():
    print("=== Edge Case Testing ===")
    
    # Test 1: Large kernel (32x32)
    try:
        P_test, Q_test = validate_conv_params(64, 64, 32, 32, 0, 1)
        print(f"Test 1 PASSED: 32x32 kernel on 64x64 input -> output {P_test}x{Q_test}")
    except Exception as e:
        print(f"Test 1 FAILED: {e}")
    
    # Test 2: Kernel larger than input
    try:
        P_test, Q_test = validate_conv_params(3, 3, 5, 5, 0, 1)
        print(f"Test 2 FAILED: Should have raised error for 5x5 kernel on 3x3 input")
    except ValueError as e:
        print(f"Test 2 PASSED: Correctly rejected oversized kernel: {e}")
    
    # Test 3: Large stride
    try:
        P_test, Q_test = validate_conv_params(10, 10, 3, 3, 0, 5)
        print(f"Test 3 PASSED: Large stride (5) -> output {P_test}x{Q_test}")
    except Exception as e:
        print(f"Test 3 FAILED: {e}")
    
    # Test 4: Invalid parameters
    try:
        P_test, Q_test = validate_conv_params(5, 5, 3, 3, 0, 0)
        print(f"Test 4 FAILED: Should have raised error for zero stride")
    except ValueError as e:
        print(f"Test 4 PASSED: Correctly rejected zero stride: {e}")
    
    # Test 5: Oversized kernel (>32x32)
    try:
        P_test, Q_test = validate_conv_params(50, 50, 33, 33, 0, 1)
        print(f"Test 5 FAILED: Should have raised error for 33x33 kernel")
    except ValueError as e:
        print(f"Test 5 PASSED: Correctly rejected oversized kernel: {e}")
    
    print("=== Edge Case Testing Complete ===")

test_edge_cases()
# Out:
# === EDGE CASE TESTING ===
# Test 1 PASSED: 32x32 kernel on 64x64 input -> output 33x33
# Test 2 PASSED: Correctly rejected oversized kernel: Invalid configuration: kernel (5x5) too large for input (3x3) with padding 0 and stride 1
# Test 3 PASSED: Large stride (5) -> output 2x2
# Test 4 PASSED: Correctly rejected zero stride: Stride must be positive
# Test 5 PASSED: Correctly rejected oversized kernel: Kernel size cannot exceed 32x32
# === EDGE CASE TESTING COMPLETE ===

# %%
def route_time(T, activation_size, output_size, kernel_size, stride, delay):
    """
    args:
        T: current time step
        activation_size: size of activation dimension (H or W)
        output_size: size of output dimension (P or Q)
        kernel_size: size of kernel dimension (R or S)
        stride: convolution stride
        delay: processing delay
    
    returns:
        dictionary mapping kernel positions to output coordinates
    """
    routing = {}
    
    for k in range(kernel_size):
        # Calculate remaining time after accounting for kernel position and delay
        remainder = T - kernel_size - (delay * k)
        
        # Check if timing is valid
        if remainder < 0 or remainder % kernel_size != 0:
            routing[k] = None
            continue
        
        # Calculate position in flattened output space
        Q = remainder // kernel_size
        
        # Convert to 2D coordinates
        i = Q // output_size
        j = Q % output_size
        
        # Validate coordinates are within bounds
        if i < output_size and j < output_size:
            routing[k] = (i, j)
        else:
            routing[k] = None
    
    return routing

# Test the routing function for different time steps
print("=== Routing Time Analysis ===")
# Use the global variables defined earlier in the notebook
try:
    print(f"Parameters: H={H}, P={P}, R={R}, stride={stride}")
    print("Time Step | Routing")
    print("-" * 40)

    for i in range(20):
        routing_result = route_time(i, H, P, R, stride, 2)
        print(f"{i:8d} | {routing_result}")
except NameError as e:
    print(f"Error: Variables not defined. Please run the parameter definition cells first.")
    print(f"Missing variable: {e}")
    # Use default values for demonstration
    H_demo, P_demo, R_demo, stride_demo = 5, 2, 4, 1
    print(f"Using demo parameters: H={H_demo}, P={P_demo}, R={R_demo}, stride={stride_demo}")
    print("Time Step | Routing")
    print("-" * 40)
    
    for i in range(20):
        routing_result = route_time(i, H_demo, P_demo, R_demo, stride_demo, 2)
        print(f"{i:8d} | {routing_result}")
# Out:
# === ROUTING TIME ANALYSIS ===
# Parameters: H=5, P=2, R=4, stride=1
# Time Step | Routing
# ----------------------------------------
#        0 | {0: None, 1: None, 2: None, 3: None}
#        1 | {0: None, 1: None, 2: None, 3: None}
#        2 | {0: None, 1: None, 2: None, 3: None}
#        3 | {0: None, 1: None, 2: None, 3: None}
#        4 | {0: (0, 0), 1: None, 2: None, 3: None}
#        5 | {0: None, 1: None, 2: None, 3: None}
#        6 | {0: None, 1: (0, 0), 2: None, 3: None}
#        7 | {0: None, 1: None, 2: None, 3: None}
#        8 | {0: (0, 1), 1: None, 2: (0, 0), 3: None}
#        9 | {0: None, 1: None, 2: None, 3: None}
#       10 | {0: None, 1: (0, 1), 2: None, 3: (0, 0)}
#       11 | {0: None, 1: None, 2: None, 3: None}
#       12 | {0: (1, 0), 1: None, 2: (0, 1), 3: None}
#       13 | {0: None, 1: None, 2: None, 3: None}
#       14 | {0: None, 1: (1, 0), 2: None, 3: (0, 1)}
#       15 | {0: None, 1: None, 2: None, 3: None}
#       16 | {0: (1, 1), 1: None, 2: (1, 0), 3: None}
#       17 | {0: None, 1: None, 2: None, 3: None}
#       18 | {0: None, 1: (1, 1), 2: None, 3: (1, 0)}
#       19 | {0: None, 1: None, 2: None, 3: None}

# %%
def enhanced_route_time(T, activation_size, output_size, kernel_size, stride, delay):
    # Input validation
    if kernel_size <= 0 or output_size <= 0 or stride <= 0:
        raise ValueError("Kernel size, output size, and stride must be positive")
    
    if delay < 0:
        raise ValueError("Delay cannot be negative")
    
    routing = {}
    
    for k in range(kernel_size):
        # Calculate effective time considering kernel position and delay
        effective_time = T - k - (delay * k)
        
        # Check if timing allows for valid processing
        if effective_time < 0:
            routing[k] = None
            continue
        
        # Calculate position considering stride
        if effective_time % stride != 0:
            routing[k] = None
            continue
        
        position = effective_time // stride
        
        # Convert to 2D coordinates
        i = position // output_size
        j = position % output_size
        
        # Validate coordinates
        if 0 <= i < output_size and 0 <= j < output_size:
            routing[k] = (i, j)
        else:
            routing[k] = None
    
    return routing

# Test enhanced routing function
print("\n=== Enhanced Routing Time Analysis ===")
try:
    print(f"Parameters: H={H}, P={P}, R={R}, stride={stride}")
    print("Time Step | Enhanced Routing")
    print("-" * 50)

    for i in range(20):
        try:
            enhanced_routing = enhanced_route_time(i, H, P, R, stride, 2)
            print(f"{i:8d} | {enhanced_routing}")
        except ValueError as e:
            print(f"{i:8d} | Error: {e}")
except NameError as e:
    print(f"Error: Variables not defined. Please run the parameter definition cells first.")
    print(f"Missing variable: {e}")
    # Use default values for demonstration
    H_demo, P_demo, R_demo, stride_demo = 5, 2, 4, 1
    print(f"Using demo parameters: H={H_demo}, P={P_demo}, R={R_demo}, stride={stride_demo}")
    print("Time Step | Enhanced Routing")
    print("-" * 50)
    
    for i in range(20):
        try:
            enhanced_routing = enhanced_route_time(i, H_demo, P_demo, R_demo, stride_demo, 2)
            print(f"{i:8d} | {enhanced_routing}")
        except ValueError as e:
            print(f"{i:8d} | Error: {e}")
# Out:
# enhanced routing time analysis
# Parameters: H=5, P=2, R=4, stride=1
# Time Step | Enhanced Routing
# --------------------------------------------------
#        0 | {0: (0, 0), 1: None, 2: None, 3: None}
#        1 | {0: (0, 1), 1: None, 2: None, 3: None}
#        2 | {0: (1, 0), 1: None, 2: None, 3: None}
#        3 | {0: (1, 1), 1: (0, 0), 2: None, 3: None}
#        4 | {0: None, 1: (0, 1), 2: None, 3: None}
#        5 | {0: None, 1: (1, 0), 2: None, 3: None}
#        6 | {0: None, 1: (1, 1), 2: (0, 0), 3: None}
#        7 | {0: None, 1: None, 2: (0, 1), 3: None}
#        8 | {0: None, 1: None, 2: (1, 0), 3: None}
#        9 | {0: None, 1: None, 2: (1, 1), 3: (0, 0)}
#       10 | {0: None, 1: None, 2: None, 3: (0, 1)}
#       11 | {0: None, 1: None, 2: None, 3: (1, 0)}
#       12 | {0: None, 1: None, 2: None, 3: (1, 1)}
#       13 | {0: None, 1: None, 2: None, 3: None}
#       14 | {0: None, 1: None, 2: None, 3: None}
#       15 | {0: None, 1: None, 2: None, 3: None}
#       16 | {0: None, 1: None, 2: None, 3: None}
#       17 | {0: None, 1: None, 2: None, 3: None}
#       18 | {0: None, 1: None, 2: None, 3: None}
#       19 | {0: None, 1: None, 2: None, 3: None}

# %%
def analyze_routing_patterns():
    print("\n=== Routing Pattern Analysis ===")
    
    # Try to use global variables, fallback to defaults if not available
    try:
        current_config = {"name": "Current Config", "H": H, "P": P, "R": R, "stride": stride}
    except NameError:
        print("Warning: Global variables not defined. Using default values.")
        current_config = {"name": "Default Config", "H": 5, "P": 2, "R": 4, "stride": 1}
    
    configs = [
        current_config,
        {"name": "Small Kernel", "H": 8, "P": 6, "R": 3, "stride": 1},
        {"name": "Large Stride", "H": 10, "P": 3, "R": 4, "stride": 3},
        {"name": "Edge Case", "H": 5, "P": 1, "R": 5, "stride": 1}
    ]
    
    for config in configs:
        print(f"\n--- {config['name']} ---")
        print(f"H={config['H']}, P={config['P']}, R={config['R']}, stride={config['stride']}")
        
        valid_routes = 0
        total_routes = 0
        
        for t in range(min(30, config['H'] * config['P'])):
            routing = route_time(t, config['H'], config['P'], config['R'], config['stride'], 2)
            
            for k, coord in routing.items():
                total_routes += 1
                if coord is not None:
                    valid_routes += 1
        
        efficiency = (valid_routes / total_routes * 100) if total_routes > 0 else 0
        print(f"Routing efficiency: {efficiency:.1f}% ({valid_routes}/{total_routes})")

analyze_routing_patterns()
# Out:
# === ROUTING PATTERN ANALYSIS ===
#
# --- Current Config ---
# H=5, P=2, R=4, stride=1
# Routing efficiency: 10.0% (4/40)
#
# --- Small Kernel ---
# H=8, P=6, R=3, stride=1
# Routing efficiency: 28.9% (26/90)
#
# --- Large Stride ---
# H=10, P=3, R=4, stride=3
# Routing efficiency: 20.0% (24/120)
#
# --- Edge Case ---
# H=5, P=1, R=5, stride=1
# Routing efficiency: 0.0% (0/25)

# %%
patches[0]
# Out:
# array([[['A0000'],
#         ['A0010'],
#         ['A0020'],
#         ['A0030']],
#
#        [['A0100'],
#         ['A0110'],
#         ['A0120'],
#         ['A0130']],
#
#        [['A0200'],
#         ['A0210'],
#         ['A0220'],
#         ['A0230']],
#
#        [['A0300'],
#         ['A0310'],
#         ['A0320'],
#         ['A0330']]], dtype='<U85')

# %%
patches[1]
# Out:
# array([[['A0010'],
#         ['A0020'],
#         ['A0030'],
#         ['A0040']],
#
#        [['A0110'],
#         ['A0120'],
#         ['A0130'],
#         ['A0140']],
#
#        [['A0210'],
#         ['A0220'],
#         ['A0230'],
#         ['A0240']],
#
#        [['A0310'],
#         ['A0320'],
#         ['A0330'],
#         ['A0340']]], dtype='<U85')
